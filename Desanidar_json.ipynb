# %%
from google.colab import drive
import os

# Montar Google Drive
drive.mount('/content/drive', force_remount=True)
folder_path = '/content/drive/MyDrive/Google Maps'


# Recorrer y mostrar archivos
for root, dirs, files in os.walk(folder_path):
    print(f'📂 Carpeta: {root}')
    for file in files:
        print(f'  📄 {file}')
# Out:
# Mounted at /content/drive
# 📂 Carpeta: /content/drive/MyDrive/Google Maps
#   📄 Diccionario de datos.gdoc
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Alabama
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Connecticut
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
#   📄 17.json
#   📄 18.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-California
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
#   📄 17.json
#   📄 18.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Arkansas
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-District_of_Columbia
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Florida
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
#   📄 17.json
#   📄 18.json
#   📄 19.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Alaska
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Colorado
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Delaware
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 7.json
#   📄 6.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Arizona
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Illinois
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Louisiana
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Idaho
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Hawaii
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 11.json
#   📄 10.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Iowa
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
#   📄 17.json
#   📄 18.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Georgia
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Kansas
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Maine
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Indiana
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Kentucky
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Michigan
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nebraska
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Massachusetts
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 14.json
#   📄 13.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 7.json
#   📄 6.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Maryland
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Missouri
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Oklahoma
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_York
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
#   📄 17.json
#   📄 18.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Ohio
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Mexico
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Oregon
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Pennsylvania
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Jersey
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-North_Dakota
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Rhode_Island
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-North_Carolina
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Washington
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Texas
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
#   📄 15.json
#   📄 16.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-South_Carolina
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
#   📄 13.json
#   📄 14.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Tennessee
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Utah
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Vermont
#   📄 1.json
#   📄 2.json
#   📄 3.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Wisconsin
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-West_Virginia
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-South_Dakota
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json
#   📄 12.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/reviews-estados/review-Wyoming
#   📄 1.json
#   📄 2.json
#   📄 3.json
# 📂 Carpeta: /content/drive/MyDrive/Google Maps/metadata-sitios
#   📄 1.json
#   📄 2.json
#   📄 3.json
#   📄 4.json
#   📄 5.json
#   📄 6.json
#   📄 7.json
#   📄 8.json
#   📄 9.json
#   📄 10.json
#   📄 11.json

# %%
file_path = '/content/drive/MyDrive/Google Maps/metadata-sitios/1.json'

# %%
with open(file_path, 'r', encoding='utf-8') as f:
    # Leer solo los primeros 1000 caracteres
    snippet = f.read(10000)
    print(snippet)
# Out:
# {"name": "Porter Pharmacy", "address": "Porter Pharmacy, 129 N Second St, Cochran, GA 31014", "gmap_id": "0x88f16e41928ff687:0x883dad4fd048e8f8", "description": null, "latitude": 32.3883, "longitude": -83.3571, "category": ["Pharmacy"], "avg_rating": 4.9, "num_of_reviews": 16, "price": null, "hours": [["Friday", "8AM\u20136PM"], ["Saturday", "8AM\u201312PM"], ["Sunday", "Closed"], ["Monday", "8AM\u20136PM"], ["Tuesday", "8AM\u20136PM"], ["Wednesday", "8AM\u201312PM"], ["Thursday", "8AM\u20136PM"]], "MISC": {"Service options": ["In-store shopping", "Same-day delivery"], "Health & safety": ["Mask required", "Staff required to disinfect surfaces between visits"], "Accessibility": ["Wheelchair accessible entrance"], "Planning": ["Quick visit"]}, "state": "Open \u22c5 Closes 6PM", "relative_results": ["0x88f16e41929435cf:0x5b2532a2885e9ef6", "0x88f16c32716531c1:0x5f19bdaa5044e4fa", "0x88f16e6e3f4a21df:0xcf495da9bb4d89ea"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us"}
# {"name": "City Textile", "address": "City Textile, 3001 E Pico Blvd, Los Angeles, CA 90023", "gmap_id": "0x80c2c98c0e3c16fd:0x29ec8a728764fdf9", "description": null, "latitude": 34.0188913, "longitude": -118.2152898, "category": ["Textile exporter"], "avg_rating": 4.5, "num_of_reviews": 6, "price": null, "hours": null, "MISC": null, "state": "Open now", "relative_results": ["0x80c2c624136ea88b:0xb0315367ed448771", "0x80c2c97cb7c52f17:0xb66ee68c1c366f2d"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x80c2c98c0e3c16fd:0x29ec8a728764fdf9?authuser=-1&hl=en&gl=us"}
# {"name": "San Soo Dang", "address": "San Soo Dang, 761 S Vermont Ave, Los Angeles, CA 90005", "gmap_id": "0x80c2c778e3b73d33:0xbdc58662a4a97d49", "description": null, "latitude": 34.0580917, "longitude": -118.2921295, "category": ["Korean restaurant"], "avg_rating": 4.4, "num_of_reviews": 18, "price": null, "hours": [["Thursday", "6:30AM\u20136PM"], ["Friday", "6:30AM\u20136PM"], ["Saturday", "6:30AM\u20136PM"], ["Sunday", "7AM\u201312PM"], ["Monday", "Closed"], ["Tuesday", "6:30AM\u20136PM"], ["Wednesday", "6:30AM\u20136PM"]], "MISC": {"Service options": ["Takeout", "Dine-in", "Delivery"], "Accessibility": ["Wheelchair accessible entrance"], "Offerings": ["Comfort food"], "Amenities": ["Good for kids"], "Atmosphere": ["Casual"]}, "state": "Open \u22c5 Closes 6PM", "relative_results": ["0x80c2c78249aba68f:0x35bf16ce61be751d", "0x80c2c79998f75fff:0xd7ca5c67e96fb778", "0x80c2b899146d7507:0xf4162c12c9cf65f8", "0x80c2c77f2d419951:0x26285631b21e324c", "0x80c2b8add9016015:0x15836f81a963b35f"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x80c2c778e3b73d33:0xbdc58662a4a97d49?authuser=-1&hl=en&gl=us"}
# {"name": "Nova Fabrics", "address": "Nova Fabrics, 2200 E 11th St, Los Angeles, CA 90021", "gmap_id": "0x80c2c89923b27a41:0x32041559418d447", "description": null, "latitude": 34.0236689, "longitude": -118.2329297, "category": ["Fabric store"], "avg_rating": 3.3, "num_of_reviews": 6, "price": null, "hours": [["Thursday", "9AM\u20135PM"], ["Friday", "9AM\u20135PM"], ["Saturday", "Closed"], ["Sunday", "Closed"], ["Monday", "9AM\u20135PM"], ["Tuesday", "9AM\u20135PM"], ["Wednesday", "9AM\u20135PM"]], "MISC": {"Service options": ["In-store shopping"], "Payments": ["Checks", "Debit cards", "Credit cards"]}, "state": "Open \u22c5 Closes 5PM", "relative_results": ["0x80c2c8811477253f:0x23a8a492df1918f7", "0x80c2c6333ea5aaa7:0x38c93218b0d5751b", "0x80c2c633235effa1:0x384bf96fe70cbbc7", "0x80c2c6295991d031:0x8516999f61103f87", "0x80c2c63331db7ec5:0x507f59d850d36691"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x80c2c89923b27a41:0x32041559418d447?authuser=-1&hl=en&gl=us"}
# {"name": "Nobel Textile Co", "address": "Nobel Textile Co, 719 E 9th St, Los Angeles, CA 90021", "gmap_id": "0x80c2c632f933b073:0xc31785961fe826a6", "description": null, "latitude": 34.0366942, "longitude": -118.2494208, "category": ["Fabric store"], "avg_rating": 4.3, "num_of_reviews": 7, "price": null, "hours": [["Thursday", "9AM\u20135PM"], ["Friday", "9AM\u20135PM"], ["Saturday", "Closed"], ["Sunday", "Closed"], ["Monday", "9AM\u20135PM"], ["Tuesday", "9AM\u20135PM"], ["Wednesday", "9AM\u20135PM"]], "MISC": {"Service options": ["In-store pickup"]}, "state": "Open \u22c5 Closes 5PM", "relative_results": ["0x80c2c62c496083d1:0xdefa11317fe870a1", "0x80c2c6333ea5aaa7:0x38c93218b0d5751b", "0x80c2c632158d209d:0xe23b0235cc969407", "0x80c2c881faa0ca0f:0xe0806e3c88dbd1"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x80c2c632f933b073:0xc31785961fe826a6?authuser=-1&hl=en&gl=us"}
# {"name": "Matrix International Textiles", "address": "Matrix International Textiles, 1363 S Bonnie Beach Pl, Commerce, CA 90023", "gmap_id": "0x80c2cf163db6bc89:0x219484e2edbcfa41", "description": null, "latitude": 34.0155047, "longitude": -118.1818394, "category": ["Fabric store"], "avg_rating": 3.5, "num_of_reviews": 6, "price": null, "hours": [["Thursday", "8:30AM\u20135:30PM"], ["Friday", "8:30AM\u20135:30PM"], ["Saturday", "Closed"], ["Sunday", "Closed"], ["Monday", "8:30AM\u20135:30PM"], ["Tuesday", "8:30AM\u20135:30PM"], ["Wednesday", "8:30AM\u20135:30PM"]], "MISC": {"Accessibility": ["Wheelchair accessible entrance"]}, "state": "Open \u22c5 Closes 5:30PM", "relative_results": ["0x80c2cf042a5d9561:0xd0024ad6f81f1335", "0x80c2c8bd8e194c6d:0xa095ca0e339428fc", "0x80c2ce4be1869c51:0x826a3f0c03e67e59", "0x80c2cf402a32f3d1:0xa4039f3a8d5c1b06"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x80c2cf163db6bc89:0x219484e2edbcfa41?authuser=-1&hl=en&gl=us"}
# {"name": "Vons Chicken", "address": "Vons Chicken, 12740 La Mirada Blvd, La Mirada, CA 90638", "gmap_id": "0x80dd2b4c8555edb7:0xfc33d65c4bdbef42", "description": null, "latitude": 33.9164023, "longitude": -118.01085499999999, "category": ["Restaurant"], "avg_rating": 4.5, "num_of_reviews": 18, "price": null, "hours": [["Thursday", "11AM\u20139:30PM"], ["Friday", "11AM\u20139:30PM"], ["Saturday", "11AM\u20139:30PM"], ["Sunday", "11AM\u20139:30PM"], ["Monday", "Closed"], ["Tuesday", "11AM\u20139:30PM"], ["Wednesday", "11AM\u20139:30PM"]], "MISC": {"Service options": ["Outdoor seating", "Curbside pickup", "No-contact delivery", "Delivery", "Takeout", "Dine-in"], "Health & safety": ["Mask required", "Staff wear masks", "Staff required to disinfect surfaces between visits"], "Popular for": ["Lunch", "Dinner", "Solo dining"], "Accessibility": ["Wheelchair accessible entrance"], "Offerings": ["Comfort food", "Quick bite", "Small plates"], "Dining options": ["Lunch", "Dinner"], "Amenities": ["Good for kids"], "Atmosphere": ["Casual"], "Crowd": ["College students"]}, "state": "Open \u22c5 Closes 9:30PM", "relative_results": null, "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x80dd2b4c8555edb7:0xfc33d65c4bdbef42?authuser=-1&hl=en&gl=us"}
# {"name": "Polished Nail Salon & Spa", "address": "Polished Nail Salon & Spa, 1330 Hickman Rd, Waukee, IA 50263", "gmap_id": "0x87ec238afdd8837b:0x2f43f2b12142bff5", "description": null, "latitude": 41.614197999999995, "longitude": -93.8472695, "category": ["Nail salon", "Waxing hair removal service"], "avg_rating": 4, "num_of_reviews": 86, "price": null, "hours": [["Thursday", "9AM\u20138PM"], ["Friday", "9AM\u20138PM"], ["Saturday", "9AM\u20137PM"], ["Sunday", "11AM\u20135PM"], ["Monday", "9AM\u20138PM"], ["Tuesday", "9AM\u20138PM"], ["Wednesday", "9AM\u20138PM"]], "MISC": {"From the business": ["Identifies as women-led"], "Highlights": ["LGBTQ friendly"], "Accessibility": ["Wheelchair accessible entrance", "Wheelchair accessible parking lot", "Wheelchair accessible restroom"], "Amenities": ["Gender-neutral restroom", "Restroom", "Wi-Fi"], "Payments": ["Debit cards", "Credit cards"]}, "state": "Open \u22c5 Closes 8PM", "relative_results": ["0x87ec2481df68e107:0x2978d64e14ca8313", "0x87ec23e8845a37e5:0xb0976da75a2ea960", "0x87ec2362d6508ce7:0xfec720720563bac7", "0x87ec2394416fe367:0x15f4806aef3573fd", "0x87ec23d7e3bef45d:0xa187e18afad628a5"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x87ec238afdd8837b:0x2f43f2b12142bff5?authuser=-1&hl=en&gl=us"}
# {"name": "Sweet Rewards Gluten Free Bakery, LLC", "address": "Sweet Rewards Gluten Free Bakery, LLC, 85 NE Dartmoor Dr, Waukee, IA 50263", "gmap_id": "0x87ec235c54d25b31:0x3b75fb5facc602f", "description": null, "latitude": 41.616079, "longitude": -93.865487, "category": ["Bakery", "Health food restaurant"], "avg_rating": 4.7, "num_of_reviews": 21, "price": null, "hours": [["Thursday", "10AM\u20135:30PM"], ["Friday", "10AM\u20135:30PM"], ["Saturday", "9AM\u201312PM"], ["Sunday", "Closed"], ["Monday", "10AM\u20135:30PM"], ["Tuesday", "10AM\u20135:30PM"], ["Wednesday", "10AM\u20135:30PM"]], "MISC": {"Service options": ["Delivery"]}, "state": "Permanently closed", "relative_results": ["0x87ee974869295555:0x95f310d065882c9b", "0x87ec20d44240e889:0xbd04c461a2e8eff6", "0x87ec2227812ac667:0x8b194dd8e3288532"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x87ec235c54d25b31:0x3b75fb5facc602f?authuser=-1&hl=en&gl=us"}
# {"name": "PeepNotes", "address": null, "gmap_id": "0x87ee85ac3cb23b4d:0x4cd1435fddc046b1", "description": null, "latitude": 41.846035, "longitude": -93.7561175, "category": ["Greeting card shop", "Service establishment"], "avg_rating": 5, "num_of_reviews": 1, "price": null, "hours": [["Thursday", "7AM\u20138PM"], ["Friday", "7AM\u20138PM"], ["Saturday", "7AM\u20138PM"], ["Sunday", "7AM\u20138PM"], ["Monday", "7AM\u20138PM"], ["Tuesday", "7AM\u20138PM"], ["Wednesday", "7AM\u20138PM"]], "MISC": null, "state": "Open \u22c5 Closes 8PM", "relative_results": ["0x87ee915d9604ea6b:0x797354b58dacd391", "0x87ee85731875ecef:0x12f7d69d02f6abec", "0x87ee99adc6d488b7:0x4970dc1193d68d4"], "url": "https://www.google.com/maps/place//data=!4m2!3m1!1s0x87ee85ac3cb23b4d:0x4cd1435fddc046b1?authuser=-1&hl=en&gl=us"}
# {"name": "Lush Family Dental", "address": "Lush Family Dental, 2505 SE E

# %% [markdown]
# ## Combinemos todos los json en un solo archivo

# %%
import os
import json
import pandas as pd
import glob

# %%
carpeta_json = '/content/drive/MyDrive/Google Maps/metadata-sitios'
salida_dir = '/content/drive/MyDrive/Descargados de Colab/parquets_chunks'

# %%
def aplanar_json(datos, prefijo=""):
    resultado = {}
    for clave, valor in datos.items():
        nueva_clave = f"{prefijo}{clave}"
        if isinstance(valor, dict):
            resultado.update(aplanar_json(valor, f"{nueva_clave}_"))
        elif isinstance(valor, list):
            for i, item in enumerate(valor):
                if isinstance(item, (dict, list)):
                    resultado.update(aplanar_json({str(i): item}, f"{nueva_clave}_"))
                else:
                    resultado[f"{nueva_clave}_{i}"] = item
        else:
            resultado[nueva_clave] = valor
    return resultado

# ===== CONFIGURACIÓN =====
os.makedirs(salida_dir, exist_ok=True)

chunk_size = 10000  # Cantidad de registros por chunk
buffer = []
chunk_id = 0

# Buscar archivos
archivos_json = glob.glob(os.path.join(carpeta_json, '*.json'))
print(f"Se encontraron {len(archivos_json)} archivos.")

for ruta_json in archivos_json:
    print(f"Procesando archivo: {os.path.basename(ruta_json)}")
    with open(ruta_json, 'r', encoding='utf-8') as f:
        for linea in f:
            try:
                data = json.loads(linea)
                data_flat = aplanar_json(data)
                buffer.append(data_flat)

                if len(buffer) >= chunk_size:
                    df_chunk = pd.DataFrame(buffer)
                    ruta_parquet = os.path.join(salida_dir, f"chunk_{chunk_id}.parquet")
                    df_chunk.to_parquet(ruta_parquet, index=False)
                    print(f"💾 Chunk {chunk_id} guardado con {len(buffer)} registros.")
                    buffer = []
                    chunk_id += 1
            except Exception as e:
                print(f"⚠️ Error leyendo línea: {e}")

# Guardar lo que quedó en el buffer
if buffer:
    df_chunk = pd.DataFrame(buffer)
    ruta_parquet = os.path.join(salida_dir, f"chunk_{chunk_id}.parquet")
    df_chunk.to_parquet(ruta_parquet, index=False)
    print(f"💾 Último chunk {chunk_id} guardado con {len(buffer)} registros.")
# Out:
# Se encontraron 0 archivos.

# %%
import pyarrow.parquet as pq
import pyarrow as pa

# Leer todos los chunks y unirlos
parquet_files = glob.glob(os.path.join(salida_dir, 'chunk_*.parquet'))
dfs = [pd.read_parquet(pq_file) for pq_file in parquet_files]

df_final = pd.concat(dfs, ignore_index=True)
df_final.to_parquet(os.path.join(salida_dir, 'unificado.parquet'), index=False)
print("✅ Archivo final unido guardado.")

# %%
import os
import glob
import pyarrow.parquet as pq
import pyarrow as pa
import pandas as pd

parquet_files = glob.glob(os.path.join(salida_dir, 'chunk_*.parquet'))

# Leer el primer archivo y obtener las columnas base
df_base = pd.read_parquet(parquet_files[0])
columnas_base = df_base.columns
schema = pa.Table.from_pandas(df_base).schema

output_path = os.path.join(salida_dir, 'aa_unificado.parquet')

with pq.ParquetWriter(output_path, schema) as writer:
    for pq_file in parquet_files:
        df = pd.read_parquet(pq_file)
        # Reindex para que todas tengan las mismas columnas, rellenando con NaN si falta alguna
        df = df.reindex(columns=columnas_base)
        table = pa.Table.from_pandas(df, schema=schema)
        writer.write_table(table)
        print(f"✅ Escrito {pq_file}")

print("✅ Archivo final unido guardado.")
# Out:
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_0.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_1.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_2.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_3.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_4.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_5.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_6.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_7.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_8.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_9.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_10.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_11.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_12.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_13.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_14.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_15.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_16.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_17.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_18.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_19.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_20.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_21.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_22.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_23.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_24.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_25.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_26.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_27.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_28.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_29.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_30.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_31.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_32.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_33.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_34.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_35.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_36.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_37.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_38.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_39.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_40.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_41.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_42.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_43.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_44.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_45.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_46.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_47.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_48.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_49.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_50.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_51.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_52.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_53.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_54.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_55.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_56.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_57.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_58.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_59.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_60.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_61.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_62.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_63.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_64.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_65.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_66.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_67.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_68.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_69.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_70.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_71.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_72.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_73.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_74.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_75.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_76.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_77.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_78.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_79.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_80.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_81.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_82.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_83.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_84.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_85.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_86.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_87.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_88.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_89.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_90.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_91.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_92.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_93.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_94.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_95.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_96.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_97.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_98.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_99.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_100.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_101.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_102.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_103.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_104.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_105.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_106.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_107.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_108.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_109.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_110.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_111.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_112.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_113.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_114.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_115.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_116.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_117.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_118.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_119.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_120.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_121.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_122.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_123.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_124.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_125.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_126.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_127.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_128.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_129.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_130.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_131.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_132.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_133.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_134.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_135.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_136.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_137.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_138.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_139.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_140.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_141.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_142.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_143.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_144.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_145.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_146.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_147.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_148.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_149.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_150.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_151.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_152.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_153.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_154.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_155.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_156.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_157.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_158.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_159.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_160.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_161.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_162.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_163.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_164.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_165.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_166.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_167.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_168.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_169.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_170.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_171.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_172.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_173.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_174.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_175.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_176.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_177.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_178.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_179.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_180.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_181.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_182.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_183.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_184.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_185.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_186.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_187.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_188.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_189.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_190.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_191.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_192.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_193.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_194.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_195.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_196.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_197.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_198.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_199.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_200.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_201.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_202.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_203.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_204.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_205.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_206.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_207.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_208.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_209.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_210.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_211.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_212.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_213.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_214.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_215.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_216.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_217.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_218.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_219.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_220.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_221.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_222.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_223.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_224.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_225.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_226.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_227.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_228.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_229.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_230.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_231.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_232.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_233.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_234.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_235.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_236.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_237.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_238.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_239.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_240.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_241.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_242.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_243.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_244.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_245.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_246.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_247.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_248.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_249.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_250.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_251.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_252.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_253.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_254.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_255.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_256.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_257.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_258.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_259.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_260.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_261.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_262.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_263.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_264.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_265.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_266.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_267.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_268.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_269.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_270.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_271.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_272.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_273.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_274.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_275.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_276.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_277.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_278.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_279.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_280.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_281.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_282.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_283.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_284.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_285.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_286.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_287.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_288.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_289.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_290.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_291.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_292.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_293.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_294.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_295.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_296.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_297.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_298.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_299.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_300.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_301.parquet
# ✅ Escrito /content/drive/MyDrive/Descargados de Colab/parquets_chunks/chunk_302.parquet
# ✅ Archivo final unido guardado.

# %%
import pandas as pd

# Ruta del archivo unificado
archivo_unificado = '/content/drive/MyDrive/Descargados de Colab/parquets_chunks/unificado.parquet'

# Cargar el parquet
df = pd.read_parquet(archivo_unificado)

# Resumen general
print("📊 Resumen del archivo unificado:\n")
print(f"✅ Filas: {df.shape[0]:,}")
print(f"✅ Columnas: {df.shape[1]:,}\n")

# Tipos de datos
print("🧬 Tipos de datos por columna:")
print(df.dtypes)

# Nulos por columna
print("\n🕳️ Cantidad de valores nulos por columna:")
print(df.isnull().sum())

# Porcentaje de nulos
print("\n📉 Porcentaje de nulos por columna:")
print((df.isnull().mean() * 100).round(2).astype(str) + '%')

# Estadísticas generales (solo numéricas)
print("\n📐 Estadísticas descriptivas:")
print(df.describe())
# Out:
# 📊 Resumen del archivo unificado:
#
# ✅ Filas: 3,025,011
# ✅ Columnas: 115
#
# 🧬 Tipos de datos por columna:
# name                         object
# address                      object
# gmap_id                      object
# description                  object
# latitude                    float64
#                              ...
# MISC_Offerings_11            object
# MISC_Atmosphere_2            object
# MISC_From the business_2     object
# MISC_Dining options_5        object
# MISC_Health & safety_6       object
# Length: 115, dtype: object
#
# 🕳️ Cantidad de valores nulos por columna:
# name                             37
# address                       80511
# gmap_id                           0
# description                 2770722
# latitude                          0
#                              ...
# MISC_Offerings_11           3019672
# MISC_Atmosphere_2           3018879
# MISC_From the business_2    3024302
# MISC_Dining options_5       3020475
# MISC_Health & safety_6      3024686
# Length: 115, dtype: int64
#
# 📉 Porcentaje de nulos por columna:
# name                          0.0%
# address                      2.66%
# gmap_id                       0.0%
# description                 91.59%
# latitude                      0.0%
#                              ...
# MISC_Offerings_11           99.82%
# MISC_Atmosphere_2            99.8%
# MISC_From the business_2    99.98%
# MISC_Dining options_5       99.85%
# MISC_Health & safety_6      99.99%
# Length: 115, dtype: object
#
# 📐 Estadísticas descriptivas:
#            latitude     longitude    avg_rating  num_of_reviews  hours  MISC  \
# count  3.025011e+06  3.025011e+06  3.025011e+06    3.025011e+06    0.0   0.0
# mean   3.743011e+01 -9.234178e+01  4.303736e+00    4.362911e+01    NaN   NaN
# std    5.424919e+00  1.635686e+01  7.127077e-01    1.429952e+02    NaN   NaN
# min   -4.092931e+01 -1.788071e+02  1.000000e+00    1.000000e+00    NaN   NaN
# 25%    3.371032e+01 -9.926497e+01  4.000000e+00    7.000000e+00    NaN   NaN
# 50%    3.827949e+01 -8.760035e+01  4.500000e+00    1.700000e+01    NaN   NaN
# 75%    4.129169e+01 -8.029520e+01  4.800000e+00    4.300000e+01    NaN   NaN
# max    8.785652e+01  1.800000e+02  5.000000e+00    9.998000e+03    NaN   NaN
#
#        relative_results  category
# count               0.0       0.0
# mean                NaN       NaN
# std                 NaN       NaN
# min                 NaN       NaN
# 25%                 NaN       NaN
# 50%                 NaN       NaN
# 75%                 NaN       NaN
# max                 NaN       NaN

# %% [markdown]
# ## Ahora trabajamos con los reviews de los estados

# %%
carpeta_json = '/content/drive/MyDrive/Google Maps/reviews-estados'
salida_dir = '/content/drive/MyDrive/Descargados de Colab/parquets_chunks_reviews'

# %%
import os
import glob
import json
import pandas as pd

def aplanar_json(datos, prefijo=""):
    resultado = {}
    for clave, valor in datos.items():
        nueva_clave = f"{prefijo}{clave}"
        if isinstance(valor, dict):
            resultado.update(aplanar_json(valor, f"{nueva_clave}_"))
        elif isinstance(valor, list):
            for i, item in enumerate(valor):
                if isinstance(item, (dict, list)):
                    resultado.update(aplanar_json({str(i): item}, f"{nueva_clave}_"))
                else:
                    resultado[f"{nueva_clave}_{i}"] = item
        else:
            resultado[nueva_clave] = valor
    return resultado

# ===== CONFIGURACIÓN =====
os.makedirs(salida_dir, exist_ok=True)

chunk_size = 10000
buffer = []
chunk_id = 0

# 🔍 Buscar todos los archivos .json en la carpeta y subcarpetas
archivos_json = glob.glob(os.path.join(carpeta_json, '**', '*.json'), recursive=True)
print(f"📁 Se encontraron {len(archivos_json)} archivos JSON en todas las subcarpetas.")

# Procesar cada archivo
for ruta_json in archivos_json:
    # Extraer el nombre del estado (sin 'review-')
    nombre_carpeta = os.path.basename(os.path.dirname(ruta_json))
    estado = nombre_carpeta.replace('review-', '')

    print(f"📄 Procesando archivo: {ruta_json} (Estado: {estado})")
    try:
        with open(ruta_json, 'r', encoding='utf-8') as f:
            for linea in f:
                try:
                    data = json.loads(linea)
                    data_flat = aplanar_json(data)
                    data_flat['estado'] = estado  # ➕ Agregar la columna estado
                    buffer.append(data_flat)

                    if len(buffer) >= chunk_size:
                        df_chunk = pd.DataFrame(buffer)
                        ruta_parquet = os.path.join(salida_dir, f"chunk_{chunk_id}.parquet")
                        df_chunk.to_parquet(ruta_parquet, index=False)
                        print(f"💾 Chunk {chunk_id} guardado con {len(buffer)} registros.")
                        buffer = []
                        chunk_id += 1
                except Exception as e:
                    print(f"⚠️ Error leyendo línea en {ruta_json}: {e}")
    except Exception as e:
        print(f"❌ Error abriendo archivo {ruta_json}: {e}")

# Guardar lo que quedó
if buffer:
    df_chunk = pd.DataFrame(buffer)
    ruta_parquet = os.path.join(salida_dir, f"chunk_{chunk_id}.parquet")
    df_chunk.to_parquet(ruta_parquet, index=False)
    print(f"💾 Último chunk {chunk_id} guardado con {len(buffer)} registros.")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 💾 Chunk 4313 guardado con 10000 registros.
# 💾 Chunk 4314 guardado con 10000 registros.
# 💾 Chunk 4315 guardado con 10000 registros.
# 💾 Chunk 4316 guardado con 10000 registros.
# 💾 Chunk 4317 guardado con 10000 registros.
# 💾 Chunk 4318 guardado con 10000 registros.
# 💾 Chunk 4319 guardado con 10000 registros.
# 💾 Chunk 4320 guardado con 10000 registros.
# 💾 Chunk 4321 guardado con 10000 registros.
# 💾 Chunk 4322 guardado con 10000 registros.
# 💾 Chunk 4323 guardado con 10000 registros.
# 💾 Chunk 4324 guardado con 10000 registros.
# 💾 Chunk 4325 guardado con 10000 registros.
# 💾 Chunk 4326 guardado con 10000 registros.
# 💾 Chunk 4327 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Massachusetts/11.json (Estado: Massachusetts)
# 💾 Chunk 4328 guardado con 10000 registros.
# 💾 Chunk 4329 guardado con 10000 registros.
# 💾 Chunk 4330 guardado con 10000 registros.
# 💾 Chunk 4331 guardado con 10000 registros.
# 💾 Chunk 4332 guardado con 10000 registros.
# 💾 Chunk 4333 guardado con 10000 registros.
# 💾 Chunk 4334 guardado con 10000 registros.
# 💾 Chunk 4335 guardado con 10000 registros.
# 💾 Chunk 4336 guardado con 10000 registros.
# 💾 Chunk 4337 guardado con 10000 registros.
# 💾 Chunk 4338 guardado con 10000 registros.
# 💾 Chunk 4339 guardado con 10000 registros.
# 💾 Chunk 4340 guardado con 10000 registros.
# 💾 Chunk 4341 guardado con 10000 registros.
# 💾 Chunk 4342 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Massachusetts/12.json (Estado: Massachusetts)
# 💾 Chunk 4343 guardado con 10000 registros.
# 💾 Chunk 4344 guardado con 10000 registros.
# 💾 Chunk 4345 guardado con 10000 registros.
# 💾 Chunk 4346 guardado con 10000 registros.
# 💾 Chunk 4347 guardado con 10000 registros.
# 💾 Chunk 4348 guardado con 10000 registros.
# 💾 Chunk 4349 guardado con 10000 registros.
# 💾 Chunk 4350 guardado con 10000 registros.
# 💾 Chunk 4351 guardado con 10000 registros.
# 💾 Chunk 4352 guardado con 10000 registros.
# 💾 Chunk 4353 guardado con 10000 registros.
# 💾 Chunk 4354 guardado con 10000 registros.
# 💾 Chunk 4355 guardado con 10000 registros.
# 💾 Chunk 4356 guardado con 10000 registros.
# 💾 Chunk 4357 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Massachusetts/13.json (Estado: Massachusetts)
# 💾 Chunk 4358 guardado con 10000 registros.
# 💾 Chunk 4359 guardado con 10000 registros.
# 💾 Chunk 4360 guardado con 10000 registros.
# 💾 Chunk 4361 guardado con 10000 registros.
# 💾 Chunk 4362 guardado con 10000 registros.
# 💾 Chunk 4363 guardado con 10000 registros.
# 💾 Chunk 4364 guardado con 10000 registros.
# 💾 Chunk 4365 guardado con 10000 registros.
# 💾 Chunk 4366 guardado con 10000 registros.
# 💾 Chunk 4367 guardado con 10000 registros.
# 💾 Chunk 4368 guardado con 10000 registros.
# 💾 Chunk 4369 guardado con 10000 registros.
# 💾 Chunk 4370 guardado con 10000 registros.
# 💾 Chunk 4371 guardado con 10000 registros.
# 💾 Chunk 4372 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Massachusetts/14.json (Estado: Massachusetts)
# 💾 Chunk 4373 guardado con 10000 registros.
# 💾 Chunk 4374 guardado con 10000 registros.
# 💾 Chunk 4375 guardado con 10000 registros.
# 💾 Chunk 4376 guardado con 10000 registros.
# 💾 Chunk 4377 guardado con 10000 registros.
# 💾 Chunk 4378 guardado con 10000 registros.
# 💾 Chunk 4379 guardado con 10000 registros.
# 💾 Chunk 4380 guardado con 10000 registros.
# 💾 Chunk 4381 guardado con 10000 registros.
# 💾 Chunk 4382 guardado con 10000 registros.
# 💾 Chunk 4383 guardado con 10000 registros.
# 💾 Chunk 4384 guardado con 10000 registros.
# 💾 Chunk 4385 guardado con 10000 registros.
# 💾 Chunk 4386 guardado con 10000 registros.
# 💾 Chunk 4387 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Massachusetts/15.json (Estado: Massachusetts)
# 💾 Chunk 4388 guardado con 10000 registros.
# 💾 Chunk 4389 guardado con 10000 registros.
# 💾 Chunk 4390 guardado con 10000 registros.
# 💾 Chunk 4391 guardado con 10000 registros.
# 💾 Chunk 4392 guardado con 10000 registros.
# 💾 Chunk 4393 guardado con 10000 registros.
# 💾 Chunk 4394 guardado con 10000 registros.
# 💾 Chunk 4395 guardado con 10000 registros.
# 💾 Chunk 4396 guardado con 10000 registros.
# 💾 Chunk 4397 guardado con 10000 registros.
# 💾 Chunk 4398 guardado con 10000 registros.
# 💾 Chunk 4399 guardado con 10000 registros.
# 💾 Chunk 4400 guardado con 10000 registros.
# 💾 Chunk 4401 guardado con 10000 registros.
# 💾 Chunk 4402 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Massachusetts/16.json (Estado: Massachusetts)
# 💾 Chunk 4403 guardado con 10000 registros.
# 💾 Chunk 4404 guardado con 10000 registros.
# 💾 Chunk 4405 guardado con 10000 registros.
# 💾 Chunk 4406 guardado con 10000 registros.
# 💾 Chunk 4407 guardado con 10000 registros.
# 💾 Chunk 4408 guardado con 10000 registros.
# 💾 Chunk 4409 guardado con 10000 registros.
# 💾 Chunk 4410 guardado con 10000 registros.
# 💾 Chunk 4411 guardado con 10000 registros.
# 💾 Chunk 4412 guardado con 10000 registros.
# 💾 Chunk 4413 guardado con 10000 registros.
# 💾 Chunk 4414 guardado con 10000 registros.
# 💾 Chunk 4415 guardado con 10000 registros.
# 💾 Chunk 4416 guardado con 10000 registros.
# 💾 Chunk 4417 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/1.json (Estado: Nevada)
# 💾 Chunk 4418 guardado con 10000 registros.
# 💾 Chunk 4419 guardado con 10000 registros.
# 💾 Chunk 4420 guardado con 10000 registros.
# 💾 Chunk 4421 guardado con 10000 registros.
# 💾 Chunk 4422 guardado con 10000 registros.
# 💾 Chunk 4423 guardado con 10000 registros.
# 💾 Chunk 4424 guardado con 10000 registros.
# 💾 Chunk 4425 guardado con 10000 registros.
# 💾 Chunk 4426 guardado con 10000 registros.
# 💾 Chunk 4427 guardado con 10000 registros.
# 💾 Chunk 4428 guardado con 10000 registros.
# 💾 Chunk 4429 guardado con 10000 registros.
# 💾 Chunk 4430 guardado con 10000 registros.
# 💾 Chunk 4431 guardado con 10000 registros.
# 💾 Chunk 4432 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/2.json (Estado: Nevada)
# 💾 Chunk 4433 guardado con 10000 registros.
# 💾 Chunk 4434 guardado con 10000 registros.
# 💾 Chunk 4435 guardado con 10000 registros.
# 💾 Chunk 4436 guardado con 10000 registros.
# 💾 Chunk 4437 guardado con 10000 registros.
# 💾 Chunk 4438 guardado con 10000 registros.
# 💾 Chunk 4439 guardado con 10000 registros.
# 💾 Chunk 4440 guardado con 10000 registros.
# 💾 Chunk 4441 guardado con 10000 registros.
# 💾 Chunk 4442 guardado con 10000 registros.
# 💾 Chunk 4443 guardado con 10000 registros.
# 💾 Chunk 4444 guardado con 10000 registros.
# 💾 Chunk 4445 guardado con 10000 registros.
# 💾 Chunk 4446 guardado con 10000 registros.
# 💾 Chunk 4447 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/3.json (Estado: Nevada)
# 💾 Chunk 4448 guardado con 10000 registros.
# 💾 Chunk 4449 guardado con 10000 registros.
# 💾 Chunk 4450 guardado con 10000 registros.
# 💾 Chunk 4451 guardado con 10000 registros.
# 💾 Chunk 4452 guardado con 10000 registros.
# 💾 Chunk 4453 guardado con 10000 registros.
# 💾 Chunk 4454 guardado con 10000 registros.
# 💾 Chunk 4455 guardado con 10000 registros.
# 💾 Chunk 4456 guardado con 10000 registros.
# 💾 Chunk 4457 guardado con 10000 registros.
# 💾 Chunk 4458 guardado con 10000 registros.
# 💾 Chunk 4459 guardado con 10000 registros.
# 💾 Chunk 4460 guardado con 10000 registros.
# 💾 Chunk 4461 guardado con 10000 registros.
# 💾 Chunk 4462 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/4.json (Estado: Nevada)
# 💾 Chunk 4463 guardado con 10000 registros.
# 💾 Chunk 4464 guardado con 10000 registros.
# 💾 Chunk 4465 guardado con 10000 registros.
# 💾 Chunk 4466 guardado con 10000 registros.
# 💾 Chunk 4467 guardado con 10000 registros.
# 💾 Chunk 4468 guardado con 10000 registros.
# 💾 Chunk 4469 guardado con 10000 registros.
# 💾 Chunk 4470 guardado con 10000 registros.
# 💾 Chunk 4471 guardado con 10000 registros.
# 💾 Chunk 4472 guardado con 10000 registros.
# 💾 Chunk 4473 guardado con 10000 registros.
# 💾 Chunk 4474 guardado con 10000 registros.
# 💾 Chunk 4475 guardado con 10000 registros.
# 💾 Chunk 4476 guardado con 10000 registros.
# 💾 Chunk 4477 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/5.json (Estado: Nevada)
# 💾 Chunk 4478 guardado con 10000 registros.
# 💾 Chunk 4479 guardado con 10000 registros.
# 💾 Chunk 4480 guardado con 10000 registros.
# 💾 Chunk 4481 guardado con 10000 registros.
# 💾 Chunk 4482 guardado con 10000 registros.
# 💾 Chunk 4483 guardado con 10000 registros.
# 💾 Chunk 4484 guardado con 10000 registros.
# 💾 Chunk 4485 guardado con 10000 registros.
# 💾 Chunk 4486 guardado con 10000 registros.
# 💾 Chunk 4487 guardado con 10000 registros.
# 💾 Chunk 4488 guardado con 10000 registros.
# 💾 Chunk 4489 guardado con 10000 registros.
# 💾 Chunk 4490 guardado con 10000 registros.
# 💾 Chunk 4491 guardado con 10000 registros.
# 💾 Chunk 4492 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/6.json (Estado: Nevada)
# 💾 Chunk 4493 guardado con 10000 registros.
# 💾 Chunk 4494 guardado con 10000 registros.
# 💾 Chunk 4495 guardado con 10000 registros.
# 💾 Chunk 4496 guardado con 10000 registros.
# 💾 Chunk 4497 guardado con 10000 registros.
# 💾 Chunk 4498 guardado con 10000 registros.
# 💾 Chunk 4499 guardado con 10000 registros.
# 💾 Chunk 4500 guardado con 10000 registros.
# 💾 Chunk 4501 guardado con 10000 registros.
# 💾 Chunk 4502 guardado con 10000 registros.
# 💾 Chunk 4503 guardado con 10000 registros.
# 💾 Chunk 4504 guardado con 10000 registros.
# 💾 Chunk 4505 guardado con 10000 registros.
# 💾 Chunk 4506 guardado con 10000 registros.
# 💾 Chunk 4507 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/7.json (Estado: Nevada)
# 💾 Chunk 4508 guardado con 10000 registros.
# 💾 Chunk 4509 guardado con 10000 registros.
# 💾 Chunk 4510 guardado con 10000 registros.
# 💾 Chunk 4511 guardado con 10000 registros.
# 💾 Chunk 4512 guardado con 10000 registros.
# 💾 Chunk 4513 guardado con 10000 registros.
# 💾 Chunk 4514 guardado con 10000 registros.
# 💾 Chunk 4515 guardado con 10000 registros.
# 💾 Chunk 4516 guardado con 10000 registros.
# 💾 Chunk 4517 guardado con 10000 registros.
# 💾 Chunk 4518 guardado con 10000 registros.
# 💾 Chunk 4519 guardado con 10000 registros.
# 💾 Chunk 4520 guardado con 10000 registros.
# 💾 Chunk 4521 guardado con 10000 registros.
# 💾 Chunk 4522 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/8.json (Estado: Nevada)
# 💾 Chunk 4523 guardado con 10000 registros.
# 💾 Chunk 4524 guardado con 10000 registros.
# 💾 Chunk 4525 guardado con 10000 registros.
# 💾 Chunk 4526 guardado con 10000 registros.
# 💾 Chunk 4527 guardado con 10000 registros.
# 💾 Chunk 4528 guardado con 10000 registros.
# 💾 Chunk 4529 guardado con 10000 registros.
# 💾 Chunk 4530 guardado con 10000 registros.
# 💾 Chunk 4531 guardado con 10000 registros.
# 💾 Chunk 4532 guardado con 10000 registros.
# 💾 Chunk 4533 guardado con 10000 registros.
# 💾 Chunk 4534 guardado con 10000 registros.
# 💾 Chunk 4535 guardado con 10000 registros.
# 💾 Chunk 4536 guardado con 10000 registros.
# 💾 Chunk 4537 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/9.json (Estado: Nevada)
# 💾 Chunk 4538 guardado con 10000 registros.
# 💾 Chunk 4539 guardado con 10000 registros.
# 💾 Chunk 4540 guardado con 10000 registros.
# 💾 Chunk 4541 guardado con 10000 registros.
# 💾 Chunk 4542 guardado con 10000 registros.
# 💾 Chunk 4543 guardado con 10000 registros.
# 💾 Chunk 4544 guardado con 10000 registros.
# 💾 Chunk 4545 guardado con 10000 registros.
# 💾 Chunk 4546 guardado con 10000 registros.
# 💾 Chunk 4547 guardado con 10000 registros.
# 💾 Chunk 4548 guardado con 10000 registros.
# 💾 Chunk 4549 guardado con 10000 registros.
# 💾 Chunk 4550 guardado con 10000 registros.
# 💾 Chunk 4551 guardado con 10000 registros.
# 💾 Chunk 4552 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/10.json (Estado: Nevada)
# 💾 Chunk 4553 guardado con 10000 registros.
# 💾 Chunk 4554 guardado con 10000 registros.
# 💾 Chunk 4555 guardado con 10000 registros.
# 💾 Chunk 4556 guardado con 10000 registros.
# 💾 Chunk 4557 guardado con 10000 registros.
# 💾 Chunk 4558 guardado con 10000 registros.
# 💾 Chunk 4559 guardado con 10000 registros.
# 💾 Chunk 4560 guardado con 10000 registros.
# 💾 Chunk 4561 guardado con 10000 registros.
# 💾 Chunk 4562 guardado con 10000 registros.
# 💾 Chunk 4563 guardado con 10000 registros.
# 💾 Chunk 4564 guardado con 10000 registros.
# 💾 Chunk 4565 guardado con 10000 registros.
# 💾 Chunk 4566 guardado con 10000 registros.
# 💾 Chunk 4567 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/11.json (Estado: Nevada)
# 💾 Chunk 4568 guardado con 10000 registros.
# 💾 Chunk 4569 guardado con 10000 registros.
# 💾 Chunk 4570 guardado con 10000 registros.
# 💾 Chunk 4571 guardado con 10000 registros.
# 💾 Chunk 4572 guardado con 10000 registros.
# 💾 Chunk 4573 guardado con 10000 registros.
# 💾 Chunk 4574 guardado con 10000 registros.
# 💾 Chunk 4575 guardado con 10000 registros.
# 💾 Chunk 4576 guardado con 10000 registros.
# 💾 Chunk 4577 guardado con 10000 registros.
# 💾 Chunk 4578 guardado con 10000 registros.
# 💾 Chunk 4579 guardado con 10000 registros.
# 💾 Chunk 4580 guardado con 10000 registros.
# 💾 Chunk 4581 guardado con 10000 registros.
# 💾 Chunk 4582 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Nevada/12.json (Estado: Nevada)
# 💾 Chunk 4583 guardado con 10000 registros.
# 💾 Chunk 4584 guardado con 10000 registros.
# 💾 Chunk 4585 guardado con 10000 registros.
# 💾 Chunk 4586 guardado con 10000 registros.
# 💾 Chunk 4587 guardado con 10000 registros.
# 💾 Chunk 4588 guardado con 10000 registros.
# 💾 Chunk 4589 guardado con 10000 registros.
# 💾 Chunk 4590 guardado con 10000 registros.
# 💾 Chunk 4591 guardado con 10000 registros.
# 💾 Chunk 4592 guardado con 10000 registros.
# 💾 Chunk 4593 guardado con 10000 registros.
# 💾 Chunk 4594 guardado con 10000 registros.
# 💾 Chunk 4595 guardado con 10000 registros.
# 💾 Chunk 4596 guardado con 10000 registros.
# 💾 Chunk 4597 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/1.json (Estado: Mississippi)
# 💾 Chunk 4598 guardado con 10000 registros.
# 💾 Chunk 4599 guardado con 10000 registros.
# 💾 Chunk 4600 guardado con 10000 registros.
# 💾 Chunk 4601 guardado con 10000 registros.
# 💾 Chunk 4602 guardado con 10000 registros.
# 💾 Chunk 4603 guardado con 10000 registros.
# 💾 Chunk 4604 guardado con 10000 registros.
# 💾 Chunk 4605 guardado con 10000 registros.
# 💾 Chunk 4606 guardado con 10000 registros.
# 💾 Chunk 4607 guardado con 10000 registros.
# 💾 Chunk 4608 guardado con 10000 registros.
# 💾 Chunk 4609 guardado con 10000 registros.
# 💾 Chunk 4610 guardado con 10000 registros.
# 💾 Chunk 4611 guardado con 10000 registros.
# 💾 Chunk 4612 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/2.json (Estado: Mississippi)
# 💾 Chunk 4613 guardado con 10000 registros.
# 💾 Chunk 4614 guardado con 10000 registros.
# 💾 Chunk 4615 guardado con 10000 registros.
# 💾 Chunk 4616 guardado con 10000 registros.
# 💾 Chunk 4617 guardado con 10000 registros.
# 💾 Chunk 4618 guardado con 10000 registros.
# 💾 Chunk 4619 guardado con 10000 registros.
# 💾 Chunk 4620 guardado con 10000 registros.
# 💾 Chunk 4621 guardado con 10000 registros.
# 💾 Chunk 4622 guardado con 10000 registros.
# 💾 Chunk 4623 guardado con 10000 registros.
# 💾 Chunk 4624 guardado con 10000 registros.
# 💾 Chunk 4625 guardado con 10000 registros.
# 💾 Chunk 4626 guardado con 10000 registros.
# 💾 Chunk 4627 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/3.json (Estado: Mississippi)
# 💾 Chunk 4628 guardado con 10000 registros.
# 💾 Chunk 4629 guardado con 10000 registros.
# 💾 Chunk 4630 guardado con 10000 registros.
# 💾 Chunk 4631 guardado con 10000 registros.
# 💾 Chunk 4632 guardado con 10000 registros.
# 💾 Chunk 4633 guardado con 10000 registros.
# 💾 Chunk 4634 guardado con 10000 registros.
# 💾 Chunk 4635 guardado con 10000 registros.
# 💾 Chunk 4636 guardado con 10000 registros.
# 💾 Chunk 4637 guardado con 10000 registros.
# 💾 Chunk 4638 guardado con 10000 registros.
# 💾 Chunk 4639 guardado con 10000 registros.
# 💾 Chunk 4640 guardado con 10000 registros.
# 💾 Chunk 4641 guardado con 10000 registros.
# 💾 Chunk 4642 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/4.json (Estado: Mississippi)
# 💾 Chunk 4643 guardado con 10000 registros.
# 💾 Chunk 4644 guardado con 10000 registros.
# 💾 Chunk 4645 guardado con 10000 registros.
# 💾 Chunk 4646 guardado con 10000 registros.
# 💾 Chunk 4647 guardado con 10000 registros.
# 💾 Chunk 4648 guardado con 10000 registros.
# 💾 Chunk 4649 guardado con 10000 registros.
# 💾 Chunk 4650 guardado con 10000 registros.
# 💾 Chunk 4651 guardado con 10000 registros.
# 💾 Chunk 4652 guardado con 10000 registros.
# 💾 Chunk 4653 guardado con 10000 registros.
# 💾 Chunk 4654 guardado con 10000 registros.
# 💾 Chunk 4655 guardado con 10000 registros.
# 💾 Chunk 4656 guardado con 10000 registros.
# 💾 Chunk 4657 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/5.json (Estado: Mississippi)
# 💾 Chunk 4658 guardado con 10000 registros.
# 💾 Chunk 4659 guardado con 10000 registros.
# 💾 Chunk 4660 guardado con 10000 registros.
# 💾 Chunk 4661 guardado con 10000 registros.
# 💾 Chunk 4662 guardado con 10000 registros.
# 💾 Chunk 4663 guardado con 10000 registros.
# 💾 Chunk 4664 guardado con 10000 registros.
# 💾 Chunk 4665 guardado con 10000 registros.
# 💾 Chunk 4666 guardado con 10000 registros.
# 💾 Chunk 4667 guardado con 10000 registros.
# 💾 Chunk 4668 guardado con 10000 registros.
# 💾 Chunk 4669 guardado con 10000 registros.
# 💾 Chunk 4670 guardado con 10000 registros.
# 💾 Chunk 4671 guardado con 10000 registros.
# 💾 Chunk 4672 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/6.json (Estado: Mississippi)
# 💾 Chunk 4673 guardado con 10000 registros.
# 💾 Chunk 4674 guardado con 10000 registros.
# 💾 Chunk 4675 guardado con 10000 registros.
# 💾 Chunk 4676 guardado con 10000 registros.
# 💾 Chunk 4677 guardado con 10000 registros.
# 💾 Chunk 4678 guardado con 10000 registros.
# 💾 Chunk 4679 guardado con 10000 registros.
# 💾 Chunk 4680 guardado con 10000 registros.
# 💾 Chunk 4681 guardado con 10000 registros.
# 💾 Chunk 4682 guardado con 10000 registros.
# 💾 Chunk 4683 guardado con 10000 registros.
# 💾 Chunk 4684 guardado con 10000 registros.
# 💾 Chunk 4685 guardado con 10000 registros.
# 💾 Chunk 4686 guardado con 10000 registros.
# 💾 Chunk 4687 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/7.json (Estado: Mississippi)
# 💾 Chunk 4688 guardado con 10000 registros.
# 💾 Chunk 4689 guardado con 10000 registros.
# 💾 Chunk 4690 guardado con 10000 registros.
# 💾 Chunk 4691 guardado con 10000 registros.
# 💾 Chunk 4692 guardado con 10000 registros.
# 💾 Chunk 4693 guardado con 10000 registros.
# 💾 Chunk 4694 guardado con 10000 registros.
# 💾 Chunk 4695 guardado con 10000 registros.
# 💾 Chunk 4696 guardado con 10000 registros.
# 💾 Chunk 4697 guardado con 10000 registros.
# 💾 Chunk 4698 guardado con 10000 registros.
# 💾 Chunk 4699 guardado con 10000 registros.
# 💾 Chunk 4700 guardado con 10000 registros.
# 💾 Chunk 4701 guardado con 10000 registros.
# 💾 Chunk 4702 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/8.json (Estado: Mississippi)
# 💾 Chunk 4703 guardado con 10000 registros.
# 💾 Chunk 4704 guardado con 10000 registros.
# 💾 Chunk 4705 guardado con 10000 registros.
# 💾 Chunk 4706 guardado con 10000 registros.
# 💾 Chunk 4707 guardado con 10000 registros.
# 💾 Chunk 4708 guardado con 10000 registros.
# 💾 Chunk 4709 guardado con 10000 registros.
# 💾 Chunk 4710 guardado con 10000 registros.
# 💾 Chunk 4711 guardado con 10000 registros.
# 💾 Chunk 4712 guardado con 10000 registros.
# 💾 Chunk 4713 guardado con 10000 registros.
# 💾 Chunk 4714 guardado con 10000 registros.
# 💾 Chunk 4715 guardado con 10000 registros.
# 💾 Chunk 4716 guardado con 10000 registros.
# 💾 Chunk 4717 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/9.json (Estado: Mississippi)
# 💾 Chunk 4718 guardado con 10000 registros.
# 💾 Chunk 4719 guardado con 10000 registros.
# 💾 Chunk 4720 guardado con 10000 registros.
# 💾 Chunk 4721 guardado con 10000 registros.
# 💾 Chunk 4722 guardado con 10000 registros.
# 💾 Chunk 4723 guardado con 10000 registros.
# 💾 Chunk 4724 guardado con 10000 registros.
# 💾 Chunk 4725 guardado con 10000 registros.
# 💾 Chunk 4726 guardado con 10000 registros.
# 💾 Chunk 4727 guardado con 10000 registros.
# 💾 Chunk 4728 guardado con 10000 registros.
# 💾 Chunk 4729 guardado con 10000 registros.
# 💾 Chunk 4730 guardado con 10000 registros.
# 💾 Chunk 4731 guardado con 10000 registros.
# 💾 Chunk 4732 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/10.json (Estado: Mississippi)
# 💾 Chunk 4733 guardado con 10000 registros.
# 💾 Chunk 4734 guardado con 10000 registros.
# 💾 Chunk 4735 guardado con 10000 registros.
# 💾 Chunk 4736 guardado con 10000 registros.
# 💾 Chunk 4737 guardado con 10000 registros.
# 💾 Chunk 4738 guardado con 10000 registros.
# 💾 Chunk 4739 guardado con 10000 registros.
# 💾 Chunk 4740 guardado con 10000 registros.
# 💾 Chunk 4741 guardado con 10000 registros.
# 💾 Chunk 4742 guardado con 10000 registros.
# 💾 Chunk 4743 guardado con 10000 registros.
# 💾 Chunk 4744 guardado con 10000 registros.
# 💾 Chunk 4745 guardado con 10000 registros.
# 💾 Chunk 4746 guardado con 10000 registros.
# 💾 Chunk 4747 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/11.json (Estado: Mississippi)
# 💾 Chunk 4748 guardado con 10000 registros.
# 💾 Chunk 4749 guardado con 10000 registros.
# 💾 Chunk 4750 guardado con 10000 registros.
# 💾 Chunk 4751 guardado con 10000 registros.
# 💾 Chunk 4752 guardado con 10000 registros.
# 💾 Chunk 4753 guardado con 10000 registros.
# 💾 Chunk 4754 guardado con 10000 registros.
# 💾 Chunk 4755 guardado con 10000 registros.
# 💾 Chunk 4756 guardado con 10000 registros.
# 💾 Chunk 4757 guardado con 10000 registros.
# 💾 Chunk 4758 guardado con 10000 registros.
# 💾 Chunk 4759 guardado con 10000 registros.
# 💾 Chunk 4760 guardado con 10000 registros.
# 💾 Chunk 4761 guardado con 10000 registros.
# 💾 Chunk 4762 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/12.json (Estado: Mississippi)
# 💾 Chunk 4763 guardado con 10000 registros.
# 💾 Chunk 4764 guardado con 10000 registros.
# 💾 Chunk 4765 guardado con 10000 registros.
# 💾 Chunk 4766 guardado con 10000 registros.
# 💾 Chunk 4767 guardado con 10000 registros.
# 💾 Chunk 4768 guardado con 10000 registros.
# 💾 Chunk 4769 guardado con 10000 registros.
# 💾 Chunk 4770 guardado con 10000 registros.
# 💾 Chunk 4771 guardado con 10000 registros.
# 💾 Chunk 4772 guardado con 10000 registros.
# 💾 Chunk 4773 guardado con 10000 registros.
# 💾 Chunk 4774 guardado con 10000 registros.
# 💾 Chunk 4775 guardado con 10000 registros.
# 💾 Chunk 4776 guardado con 10000 registros.
# 💾 Chunk 4777 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/14.json (Estado: Mississippi)
# 💾 Chunk 4778 guardado con 10000 registros.
# 💾 Chunk 4779 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Mississippi/13.json (Estado: Mississippi)
# 💾 Chunk 4780 guardado con 10000 registros.
# 💾 Chunk 4781 guardado con 10000 registros.
# 💾 Chunk 4782 guardado con 10000 registros.
# 💾 Chunk 4783 guardado con 10000 registros.
# 💾 Chunk 4784 guardado con 10000 registros.
# 💾 Chunk 4785 guardado con 10000 registros.
# 💾 Chunk 4786 guardado con 10000 registros.
# 💾 Chunk 4787 guardado con 10000 registros.
# 💾 Chunk 4788 guardado con 10000 registros.
# 💾 Chunk 4789 guardado con 10000 registros.
# 💾 Chunk 4790 guardado con 10000 registros.
# 💾 Chunk 4791 guardado con 10000 registros.
# 💾 Chunk 4792 guardado con 10000 registros.
# 💾 Chunk 4793 guardado con 10000 registros.
# 💾 Chunk 4794 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/1.json (Estado: Minnesota)
# 💾 Chunk 4795 guardado con 10000 registros.
# 💾 Chunk 4796 guardado con 10000 registros.
# 💾 Chunk 4797 guardado con 10000 registros.
# 💾 Chunk 4798 guardado con 10000 registros.
# 💾 Chunk 4799 guardado con 10000 registros.
# 💾 Chunk 4800 guardado con 10000 registros.
# 💾 Chunk 4801 guardado con 10000 registros.
# 💾 Chunk 4802 guardado con 10000 registros.
# 💾 Chunk 4803 guardado con 10000 registros.
# 💾 Chunk 4804 guardado con 10000 registros.
# 💾 Chunk 4805 guardado con 10000 registros.
# 💾 Chunk 4806 guardado con 10000 registros.
# 💾 Chunk 4807 guardado con 10000 registros.
# 💾 Chunk 4808 guardado con 10000 registros.
# 💾 Chunk 4809 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/2.json (Estado: Minnesota)
# 💾 Chunk 4810 guardado con 10000 registros.
# 💾 Chunk 4811 guardado con 10000 registros.
# 💾 Chunk 4812 guardado con 10000 registros.
# 💾 Chunk 4813 guardado con 10000 registros.
# 💾 Chunk 4814 guardado con 10000 registros.
# 💾 Chunk 4815 guardado con 10000 registros.
# 💾 Chunk 4816 guardado con 10000 registros.
# 💾 Chunk 4817 guardado con 10000 registros.
# 💾 Chunk 4818 guardado con 10000 registros.
# 💾 Chunk 4819 guardado con 10000 registros.
# 💾 Chunk 4820 guardado con 10000 registros.
# 💾 Chunk 4821 guardado con 10000 registros.
# 💾 Chunk 4822 guardado con 10000 registros.
# 💾 Chunk 4823 guardado con 10000 registros.
# 💾 Chunk 4824 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/3.json (Estado: Minnesota)
# 💾 Chunk 4825 guardado con 10000 registros.
# 💾 Chunk 4826 guardado con 10000 registros.
# 💾 Chunk 4827 guardado con 10000 registros.
# 💾 Chunk 4828 guardado con 10000 registros.
# 💾 Chunk 4829 guardado con 10000 registros.
# 💾 Chunk 4830 guardado con 10000 registros.
# 💾 Chunk 4831 guardado con 10000 registros.
# 💾 Chunk 4832 guardado con 10000 registros.
# 💾 Chunk 4833 guardado con 10000 registros.
# 💾 Chunk 4834 guardado con 10000 registros.
# 💾 Chunk 4835 guardado con 10000 registros.
# 💾 Chunk 4836 guardado con 10000 registros.
# 💾 Chunk 4837 guardado con 10000 registros.
# 💾 Chunk 4838 guardado con 10000 registros.
# 💾 Chunk 4839 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/4.json (Estado: Minnesota)
# 💾 Chunk 4840 guardado con 10000 registros.
# 💾 Chunk 4841 guardado con 10000 registros.
# 💾 Chunk 4842 guardado con 10000 registros.
# 💾 Chunk 4843 guardado con 10000 registros.
# 💾 Chunk 4844 guardado con 10000 registros.
# 💾 Chunk 4845 guardado con 10000 registros.
# 💾 Chunk 4846 guardado con 10000 registros.
# 💾 Chunk 4847 guardado con 10000 registros.
# 💾 Chunk 4848 guardado con 10000 registros.
# 💾 Chunk 4849 guardado con 10000 registros.
# 💾 Chunk 4850 guardado con 10000 registros.
# 💾 Chunk 4851 guardado con 10000 registros.
# 💾 Chunk 4852 guardado con 10000 registros.
# 💾 Chunk 4853 guardado con 10000 registros.
# 💾 Chunk 4854 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/5.json (Estado: Minnesota)
# 💾 Chunk 4855 guardado con 10000 registros.
# 💾 Chunk 4856 guardado con 10000 registros.
# 💾 Chunk 4857 guardado con 10000 registros.
# 💾 Chunk 4858 guardado con 10000 registros.
# 💾 Chunk 4859 guardado con 10000 registros.
# 💾 Chunk 4860 guardado con 10000 registros.
# 💾 Chunk 4861 guardado con 10000 registros.
# 💾 Chunk 4862 guardado con 10000 registros.
# 💾 Chunk 4863 guardado con 10000 registros.
# 💾 Chunk 4864 guardado con 10000 registros.
# 💾 Chunk 4865 guardado con 10000 registros.
# 💾 Chunk 4866 guardado con 10000 registros.
# 💾 Chunk 4867 guardado con 10000 registros.
# 💾 Chunk 4868 guardado con 10000 registros.
# 💾 Chunk 4869 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/6.json (Estado: Minnesota)
# 💾 Chunk 4870 guardado con 10000 registros.
# 💾 Chunk 4871 guardado con 10000 registros.
# 💾 Chunk 4872 guardado con 10000 registros.
# 💾 Chunk 4873 guardado con 10000 registros.
# 💾 Chunk 4874 guardado con 10000 registros.
# 💾 Chunk 4875 guardado con 10000 registros.
# 💾 Chunk 4876 guardado con 10000 registros.
# 💾 Chunk 4877 guardado con 10000 registros.
# 💾 Chunk 4878 guardado con 10000 registros.
# 💾 Chunk 4879 guardado con 10000 registros.
# 💾 Chunk 4880 guardado con 10000 registros.
# 💾 Chunk 4881 guardado con 10000 registros.
# 💾 Chunk 4882 guardado con 10000 registros.
# 💾 Chunk 4883 guardado con 10000 registros.
# 💾 Chunk 4884 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/7.json (Estado: Minnesota)
# 💾 Chunk 4885 guardado con 10000 registros.
# 💾 Chunk 4886 guardado con 10000 registros.
# 💾 Chunk 4887 guardado con 10000 registros.
# 💾 Chunk 4888 guardado con 10000 registros.
# 💾 Chunk 4889 guardado con 10000 registros.
# 💾 Chunk 4890 guardado con 10000 registros.
# 💾 Chunk 4891 guardado con 10000 registros.
# 💾 Chunk 4892 guardado con 10000 registros.
# 💾 Chunk 4893 guardado con 10000 registros.
# 💾 Chunk 4894 guardado con 10000 registros.
# 💾 Chunk 4895 guardado con 10000 registros.
# 💾 Chunk 4896 guardado con 10000 registros.
# 💾 Chunk 4897 guardado con 10000 registros.
# 💾 Chunk 4898 guardado con 10000 registros.
# 💾 Chunk 4899 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/8.json (Estado: Minnesota)
# 💾 Chunk 4900 guardado con 10000 registros.
# 💾 Chunk 4901 guardado con 10000 registros.
# 💾 Chunk 4902 guardado con 10000 registros.
# 💾 Chunk 4903 guardado con 10000 registros.
# 💾 Chunk 4904 guardado con 10000 registros.
# 💾 Chunk 4905 guardado con 10000 registros.
# 💾 Chunk 4906 guardado con 10000 registros.
# 💾 Chunk 4907 guardado con 10000 registros.
# 💾 Chunk 4908 guardado con 10000 registros.
# 💾 Chunk 4909 guardado con 10000 registros.
# 💾 Chunk 4910 guardado con 10000 registros.
# 💾 Chunk 4911 guardado con 10000 registros.
# 💾 Chunk 4912 guardado con 10000 registros.
# 💾 Chunk 4913 guardado con 10000 registros.
# 💾 Chunk 4914 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/9.json (Estado: Minnesota)
# 💾 Chunk 4915 guardado con 10000 registros.
# 💾 Chunk 4916 guardado con 10000 registros.
# 💾 Chunk 4917 guardado con 10000 registros.
# 💾 Chunk 4918 guardado con 10000 registros.
# 💾 Chunk 4919 guardado con 10000 registros.
# 💾 Chunk 4920 guardado con 10000 registros.
# 💾 Chunk 4921 guardado con 10000 registros.
# 💾 Chunk 4922 guardado con 10000 registros.
# 💾 Chunk 4923 guardado con 10000 registros.
# 💾 Chunk 4924 guardado con 10000 registros.
# 💾 Chunk 4925 guardado con 10000 registros.
# 💾 Chunk 4926 guardado con 10000 registros.
# 💾 Chunk 4927 guardado con 10000 registros.
# 💾 Chunk 4928 guardado con 10000 registros.
# 💾 Chunk 4929 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/10.json (Estado: Minnesota)
# 💾 Chunk 4930 guardado con 10000 registros.
# 💾 Chunk 4931 guardado con 10000 registros.
# 💾 Chunk 4932 guardado con 10000 registros.
# 💾 Chunk 4933 guardado con 10000 registros.
# 💾 Chunk 4934 guardado con 10000 registros.
# 💾 Chunk 4935 guardado con 10000 registros.
# 💾 Chunk 4936 guardado con 10000 registros.
# 💾 Chunk 4937 guardado con 10000 registros.
# 💾 Chunk 4938 guardado con 10000 registros.
# 💾 Chunk 4939 guardado con 10000 registros.
# 💾 Chunk 4940 guardado con 10000 registros.
# 💾 Chunk 4941 guardado con 10000 registros.
# 💾 Chunk 4942 guardado con 10000 registros.
# 💾 Chunk 4943 guardado con 10000 registros.
# 💾 Chunk 4944 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/11.json (Estado: Minnesota)
# 💾 Chunk 4945 guardado con 10000 registros.
# 💾 Chunk 4946 guardado con 10000 registros.
# 💾 Chunk 4947 guardado con 10000 registros.
# 💾 Chunk 4948 guardado con 10000 registros.
# 💾 Chunk 4949 guardado con 10000 registros.
# 💾 Chunk 4950 guardado con 10000 registros.
# 💾 Chunk 4951 guardado con 10000 registros.
# 💾 Chunk 4952 guardado con 10000 registros.
# 💾 Chunk 4953 guardado con 10000 registros.
# 💾 Chunk 4954 guardado con 10000 registros.
# 💾 Chunk 4955 guardado con 10000 registros.
# 💾 Chunk 4956 guardado con 10000 registros.
# 💾 Chunk 4957 guardado con 10000 registros.
# 💾 Chunk 4958 guardado con 10000 registros.
# 💾 Chunk 4959 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Minnesota/12.json (Estado: Minnesota)
# 💾 Chunk 4960 guardado con 10000 registros.
# 💾 Chunk 4961 guardado con 10000 registros.
# 💾 Chunk 4962 guardado con 10000 registros.
# 💾 Chunk 4963 guardado con 10000 registros.
# 💾 Chunk 4964 guardado con 10000 registros.
# 💾 Chunk 4965 guardado con 10000 registros.
# 💾 Chunk 4966 guardado con 10000 registros.
# 💾 Chunk 4967 guardado con 10000 registros.
# 💾 Chunk 4968 guardado con 10000 registros.
# 💾 Chunk 4969 guardado con 10000 registros.
# 💾 Chunk 4970 guardado con 10000 registros.
# 💾 Chunk 4971 guardado con 10000 registros.
# 💾 Chunk 4972 guardado con 10000 registros.
# 💾 Chunk 4973 guardado con 10000 registros.
# 💾 Chunk 4974 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/1.json (Estado: New_Hampshire)
# 💾 Chunk 4975 guardado con 10000 registros.
# 💾 Chunk 4976 guardado con 10000 registros.
# 💾 Chunk 4977 guardado con 10000 registros.
# 💾 Chunk 4978 guardado con 10000 registros.
# 💾 Chunk 4979 guardado con 10000 registros.
# 💾 Chunk 4980 guardado con 10000 registros.
# 💾 Chunk 4981 guardado con 10000 registros.
# 💾 Chunk 4982 guardado con 10000 registros.
# 💾 Chunk 4983 guardado con 10000 registros.
# 💾 Chunk 4984 guardado con 10000 registros.
# 💾 Chunk 4985 guardado con 10000 registros.
# 💾 Chunk 4986 guardado con 10000 registros.
# 💾 Chunk 4987 guardado con 10000 registros.
# 💾 Chunk 4988 guardado con 10000 registros.
# 💾 Chunk 4989 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/2.json (Estado: New_Hampshire)
# 💾 Chunk 4990 guardado con 10000 registros.
# 💾 Chunk 4991 guardado con 10000 registros.
# 💾 Chunk 4992 guardado con 10000 registros.
# 💾 Chunk 4993 guardado con 10000 registros.
# 💾 Chunk 4994 guardado con 10000 registros.
# 💾 Chunk 4995 guardado con 10000 registros.
# 💾 Chunk 4996 guardado con 10000 registros.
# 💾 Chunk 4997 guardado con 10000 registros.
# 💾 Chunk 4998 guardado con 10000 registros.
# 💾 Chunk 4999 guardado con 10000 registros.
# 💾 Chunk 5000 guardado con 10000 registros.
# 💾 Chunk 5001 guardado con 10000 registros.
# 💾 Chunk 5002 guardado con 10000 registros.
# 💾 Chunk 5003 guardado con 10000 registros.
# 💾 Chunk 5004 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/3.json (Estado: New_Hampshire)
# 💾 Chunk 5005 guardado con 10000 registros.
# 💾 Chunk 5006 guardado con 10000 registros.
# 💾 Chunk 5007 guardado con 10000 registros.
# 💾 Chunk 5008 guardado con 10000 registros.
# 💾 Chunk 5009 guardado con 10000 registros.
# 💾 Chunk 5010 guardado con 10000 registros.
# 💾 Chunk 5011 guardado con 10000 registros.
# 💾 Chunk 5012 guardado con 10000 registros.
# 💾 Chunk 5013 guardado con 10000 registros.
# 💾 Chunk 5014 guardado con 10000 registros.
# 💾 Chunk 5015 guardado con 10000 registros.
# 💾 Chunk 5016 guardado con 10000 registros.
# 💾 Chunk 5017 guardado con 10000 registros.
# 💾 Chunk 5018 guardado con 10000 registros.
# 💾 Chunk 5019 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/4.json (Estado: New_Hampshire)
# 💾 Chunk 5020 guardado con 10000 registros.
# 💾 Chunk 5021 guardado con 10000 registros.
# 💾 Chunk 5022 guardado con 10000 registros.
# 💾 Chunk 5023 guardado con 10000 registros.
# 💾 Chunk 5024 guardado con 10000 registros.
# 💾 Chunk 5025 guardado con 10000 registros.
# 💾 Chunk 5026 guardado con 10000 registros.
# 💾 Chunk 5027 guardado con 10000 registros.
# 💾 Chunk 5028 guardado con 10000 registros.
# 💾 Chunk 5029 guardado con 10000 registros.
# 💾 Chunk 5030 guardado con 10000 registros.
# 💾 Chunk 5031 guardado con 10000 registros.
# 💾 Chunk 5032 guardado con 10000 registros.
# 💾 Chunk 5033 guardado con 10000 registros.
# 💾 Chunk 5034 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/5.json (Estado: New_Hampshire)
# 💾 Chunk 5035 guardado con 10000 registros.
# 💾 Chunk 5036 guardado con 10000 registros.
# 💾 Chunk 5037 guardado con 10000 registros.
# 💾 Chunk 5038 guardado con 10000 registros.
# 💾 Chunk 5039 guardado con 10000 registros.
# 💾 Chunk 5040 guardado con 10000 registros.
# 💾 Chunk 5041 guardado con 10000 registros.
# 💾 Chunk 5042 guardado con 10000 registros.
# 💾 Chunk 5043 guardado con 10000 registros.
# 💾 Chunk 5044 guardado con 10000 registros.
# 💾 Chunk 5045 guardado con 10000 registros.
# 💾 Chunk 5046 guardado con 10000 registros.
# 💾 Chunk 5047 guardado con 10000 registros.
# 💾 Chunk 5048 guardado con 10000 registros.
# 💾 Chunk 5049 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/6.json (Estado: New_Hampshire)
# 💾 Chunk 5050 guardado con 10000 registros.
# 💾 Chunk 5051 guardado con 10000 registros.
# 💾 Chunk 5052 guardado con 10000 registros.
# 💾 Chunk 5053 guardado con 10000 registros.
# 💾 Chunk 5054 guardado con 10000 registros.
# 💾 Chunk 5055 guardado con 10000 registros.
# 💾 Chunk 5056 guardado con 10000 registros.
# 💾 Chunk 5057 guardado con 10000 registros.
# 💾 Chunk 5058 guardado con 10000 registros.
# 💾 Chunk 5059 guardado con 10000 registros.
# 💾 Chunk 5060 guardado con 10000 registros.
# 💾 Chunk 5061 guardado con 10000 registros.
# 💾 Chunk 5062 guardado con 10000 registros.
# 💾 Chunk 5063 guardado con 10000 registros.
# 💾 Chunk 5064 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/7.json (Estado: New_Hampshire)
# 💾 Chunk 5065 guardado con 10000 registros.
# 💾 Chunk 5066 guardado con 10000 registros.
# 💾 Chunk 5067 guardado con 10000 registros.
# 💾 Chunk 5068 guardado con 10000 registros.
# 💾 Chunk 5069 guardado con 10000 registros.
# 💾 Chunk 5070 guardado con 10000 registros.
# 💾 Chunk 5071 guardado con 10000 registros.
# 💾 Chunk 5072 guardado con 10000 registros.
# 💾 Chunk 5073 guardado con 10000 registros.
# 💾 Chunk 5074 guardado con 10000 registros.
# 💾 Chunk 5075 guardado con 10000 registros.
# 💾 Chunk 5076 guardado con 10000 registros.
# 💾 Chunk 5077 guardado con 10000 registros.
# 💾 Chunk 5078 guardado con 10000 registros.
# 💾 Chunk 5079 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/8.json (Estado: New_Hampshire)
# 💾 Chunk 5080 guardado con 10000 registros.
# 💾 Chunk 5081 guardado con 10000 registros.
# 💾 Chunk 5082 guardado con 10000 registros.
# 💾 Chunk 5083 guardado con 10000 registros.
# 💾 Chunk 5084 guardado con 10000 registros.
# 💾 Chunk 5085 guardado con 10000 registros.
# 💾 Chunk 5086 guardado con 10000 registros.
# 💾 Chunk 5087 guardado con 10000 registros.
# 💾 Chunk 5088 guardado con 10000 registros.
# 💾 Chunk 5089 guardado con 10000 registros.
# 💾 Chunk 5090 guardado con 10000 registros.
# 💾 Chunk 5091 guardado con 10000 registros.
# 💾 Chunk 5092 guardado con 10000 registros.
# 💾 Chunk 5093 guardado con 10000 registros.
# 💾 Chunk 5094 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-New_Hampshire/9.json (Estado: New_Hampshire)
# 💾 Chunk 5095 guardado con 10000 registros.
# 💾 Chunk 5096 guardado con 10000 registros.
# 💾 Chunk 5097 guardado con 10000 registros.
# 💾 Chunk 5098 guardado con 10000 registros.
# 💾 Chunk 5099 guardado con 10000 registros.
# 💾 Chunk 5100 guardado con 10000 registros.
# 💾 Chunk 5101 guardado con 10000 registros.
# 💾 Chunk 5102 guardado con 10000 registros.
# 💾 Chunk 5103 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana/1.json (Estado: Montana)
# 💾 Chunk 5104 guardado con 10000 registros.
# 💾 Chunk 5105 guardado con 10000 registros.
# 💾 Chunk 5106 guardado con 10000 registros.
# 💾 Chunk 5107 guardado con 10000 registros.
# 💾 Chunk 5108 guardado con 10000 registros.
# 💾 Chunk 5109 guardado con 10000 registros.
# 💾 Chunk 5110 guardado con 10000 registros.
# 💾 Chunk 5111 guardado con 10000 registros.
# 💾 Chunk 5112 guardado con 10000 registros.
# 💾 Chunk 5113 guardado con 10000 registros.
# 💾 Chunk 5114 guardado con 10000 registros.
# 💾 Chunk 5115 guardado con 10000 registros.
# 💾 Chunk 5116 guardado con 10000 registros.
# 💾 Chunk 5117 guardado con 10000 registros.
# 💾 Chunk 5118 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana/2.json (Estado: Montana)
# 💾 Chunk 5119 guardado con 10000 registros.
# 💾 Chunk 5120 guardado con 10000 registros.
# 💾 Chunk 5121 guardado con 10000 registros.
# 💾 Chunk 5122 guardado con 10000 registros.
# 💾 Chunk 5123 guardado con 10000 registros.
# 💾 Chunk 5124 guardado con 10000 registros.
# 💾 Chunk 5125 guardado con 10000 registros.
# 💾 Chunk 5126 guardado con 10000 registros.
# 💾 Chunk 5127 guardado con 10000 registros.
# 💾 Chunk 5128 guardado con 10000 registros.
# 💾 Chunk 5129 guardado con 10000 registros.
# 💾 Chunk 5130 guardado con 10000 registros.
# 💾 Chunk 5131 guardado con 10000 registros.
# 💾 Chunk 5132 guardado con 10000 registros.
# 💾 Chunk 5133 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana/3.json (Estado: Montana)
# 💾 Chunk 5134 guardado con 10000 registros.
# 💾 Chunk 5135 guardado con 10000 registros.
# 💾 Chunk 5136 guardado con 10000 registros.
# 💾 Chunk 5137 guardado con 10000 registros.
# 💾 Chunk 5138 guardado con 10000 registros.
# 💾 Chunk 5139 guardado con 10000 registros.
# 💾 Chunk 5140 guardado con 10000 registros.
# 💾 Chunk 5141 guardado con 10000 registros.
# 💾 Chunk 5142 guardado con 10000 registros.
# 💾 Chunk 5143 guardado con 10000 registros.
# 💾 Chunk 5144 guardado con 10000 registros.
# 💾 Chunk 5145 guardado con 10000 registros.
# 💾 Chunk 5146 guardado con 10000 registros.
# 💾 Chunk 5147 guardado con 10000 registros.
# 💾 Chunk 5148 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana/4.json (Estado: Montana)
# 💾 Chunk 5149 guardado con 10000 registros.
# 💾 Chunk 5150 guardado con 10000 registros.
# 💾 Chunk 5151 guardado con 10000 registros.
# 💾 Chunk 5152 guardado con 10000 registros.
# 💾 Chunk 5153 guardado con 10000 registros.
# 💾 Chunk 5154 guardado con 10000 registros.
# 💾 Chunk 5155 guardado con 10000 registros.
# 💾 Chunk 5156 guardado con 10000 registros.
# 💾 Chunk 5157 guardado con 10000 registros.
# 💾 Chunk 5158 guardado con 10000 registros.
# 💾 Chunk 5159 guardado con 10000 registros.
# 💾 Chunk 5160 guardado con 10000 registros.
# 💾 Chunk 5161 guardado con 10000 registros.
# 💾 Chunk 5162 guardado con 10000 registros.
# 💾 Chunk 5163 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana/5.json (Estado: Montana)
# 💾 Chunk 5164 guardado con 10000 registros.
# 💾 Chunk 5165 guardado con 10000 registros.
# 💾 Chunk 5166 guardado con 10000 registros.
# 💾 Chunk 5167 guardado con 10000 registros.
# 💾 Chunk 5168 guardado con 10000 registros.
# 💾 Chunk 5169 guardado con 10000 registros.
# 💾 Chunk 5170 guardado con 10000 registros.
# 💾 Chunk 5171 guardado con 10000 registros.
# 💾 Chunk 5172 guardado con 10000 registros.
# 💾 Chunk 5173 guardado con 10000 registros.
# 💾 Chunk 5174 guardado con 10000 registros.
# 💾 Chunk 5175 guardado con 10000 registros.
# 💾 Chunk 5176 guardado con 10000 registros.
# 💾 Chunk 5177 guardado con 10000 registros.
# 💾 Chunk 5178 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana/7.json (Estado: Montana)
# 💾 Chunk 5179 guardado con 10000 registros.
# 💾 Chunk 5180 guardado con 10000 registros.
# 💾 Chunk 5181 guardado con 10000 registros.
# 💾 Chunk 5182 guardado con 10000 registros.
# 💾 Chunk 5183 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Montana/6.json (Estado: Montana)
# 💾 Chunk 5184 guardado con 10000 registros.
# 💾 Chunk 5185 guardado con 10000 registros.
# 💾 Chunk 5186 guardado con 10000 registros.
# 💾 Chunk 5187 guardado con 10000 registros.
# 💾 Chunk 5188 guardado con 10000 registros.
# 💾 Chunk 5189 guardado con 10000 registros.
# 💾 Chunk 5190 guardado con 10000 registros.
# 💾 Chunk 5191 guardado con 10000 registros.
# 💾 Chunk 5192 guardado con 10000 registros.
# 💾 Chunk 5193 guardado con 10000 registros.
# 💾 Chunk 5194 guardado con 10000 registros.
# 💾 Chunk 5195 guardado con 10000 registros.
# 💾 Chunk 5196 guardado con 10000 registros.
# 💾 Chunk 5197 guardado con 10000 registros.
# 💾 Chunk 5198 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Maryland/1.json (Estado: Maryland)
# 💾 Chunk 5199 guardado con 10000 registros.
# 💾 Chunk 5200 guardado con 10000 registros.
# 💾 Chunk 5201 guardado con 10000 registros.
# 💾 Chunk 5202 guardado con 10000 registros.
# 💾 Chunk 5203 guardado con 10000 registros.
# 💾 Chunk 5204 guardado con 10000 registros.
# 💾 Chunk 5205 guardado con 10000 registros.
# 💾 Chunk 5206 guardado con 10000 registros.
# 💾 Chunk 5207 guardado con 10000 registros.
# 💾 Chunk 5208 guardado con 10000 registros.
# 💾 Chunk 5209 guardado con 10000 registros.
# 💾 Chunk 5210 guardado con 10000 registros.
# 💾 Chunk 5211 guardado con 10000 registros.
# 💾 Chunk 5212 guardado con 10000 registros.
# 💾 Chunk 5213 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Maryland/2.json (Estado: Maryland)
# 💾 Chunk 5214 guardado con 10000 registros.
# 💾 Chunk 5215 guardado con 10000 registros.
# 💾 Chunk 5216 guardado con 10000 registros.
# 💾 Chunk 5217 guardado con 10000 registros.
# 💾 Chunk 5218 guardado con 10000 registros.
# 💾 Chunk 5219 guardado con 10000 registros.
# 💾 Chunk 5220 guardado con 10000 registros.
# 💾 Chunk 5221 guardado con 10000 registros.
# 💾 Chunk 5222 guardado con 10000 registros.
# 💾 Chunk 5223 guardado con 10000 registros.
# 💾 Chunk 5224 guardado con 10000 registros.
# 💾 Chunk 5225 guardado con 10000 registros.
# 💾 Chunk 5226 guardado con 10000 registros.
# 💾 Chunk 5227 guardado con 10000 registros.
# 💾 Chunk 5228 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Maryland/3.json (Estado: Maryland)
# 💾 Chunk 5229 guardado con 10000 registros.
# 💾 Chunk 5230 guardado con 10000 registros.
# 💾 Chunk 5231 guardado con 10000 registros.
# 💾 Chunk 5232 guardado con 10000 registros.
# 💾 Chunk 5233 guardado con 10000 registros.
# 💾 Chunk 5234 guardado con 10000 registros.
# 💾 Chunk 5235 guardado con 10000 registros.
# 💾 Chunk 5236 guardado con 10000 registros.
# 💾 Chunk 5237 guardado con 10000 registros.
# 💾 Chunk 5238 guardado con 10000 registros.
# 💾 Chunk 5239 guardado con 10000 registros.
# 💾 Chunk 5240 guardado con 10000 registros.
# 💾 Chunk 5241 guardado con 10000 registros.
# 💾 Chunk 5242 guardado con 10000 registros.
# 💾 Chunk 5243 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Maryland/4.json (Estado: Maryland)
# 💾 Chunk 5244 guardado con 10000 registros.
# 💾 Chunk 5245 guardado con 10000 registros.
# 💾 Chunk 5246 guardado con 10000 registros.
# 💾 Chunk 5247 guardado con 10000 registros.
# 💾 Chunk 5248 guardado con 10000 registros.
# 💾 Chunk 5249 guardado con 10000 registros.
# 💾 Chunk 5250 guardado con 10000 registros.
# ...
# 💾 Chunk 8685 guardado con 10000 registros.
# 💾 Chunk 8686 guardado con 10000 registros.
# 💾 Chunk 8687 guardado con 10000 registros.
# 💾 Chunk 8688 guardado con 10000 registros.
# 💾 Chunk 8689 guardado con 10000 registros.
# 💾 Chunk 8690 guardado con 10000 registros.
# 💾 Chunk 8691 guardado con 10000 registros.
# 💾 Chunk 8692 guardado con 10000 registros.
# 💾 Chunk 8693 guardado con 10000 registros.
# 💾 Chunk 8694 guardado con 10000 registros.
# 💾 Chunk 8695 guardado con 10000 registros.
# 💾 Chunk 8696 guardado con 10000 registros.
# 💾 Chunk 8697 guardado con 10000 registros.
# 💾 Chunk 8698 guardado con 10000 registros.
# 💾 Chunk 8699 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-West_Virginia/7.json (Estado: West_Virginia)
# 💾 Chunk 8700 guardado con 10000 registros.
# 💾 Chunk 8701 guardado con 10000 registros.
# 💾 Chunk 8702 guardado con 10000 registros.
# 💾 Chunk 8703 guardado con 10000 registros.
# 💾 Chunk 8704 guardado con 10000 registros.
# 💾 Chunk 8705 guardado con 10000 registros.
# 💾 Chunk 8706 guardado con 10000 registros.
# 💾 Chunk 8707 guardado con 10000 registros.
# 💾 Chunk 8708 guardado con 10000 registros.
# 💾 Chunk 8709 guardado con 10000 registros.
# 💾 Chunk 8710 guardado con 10000 registros.
# 💾 Chunk 8711 guardado con 10000 registros.
# 💾 Chunk 8712 guardado con 10000 registros.
# 💾 Chunk 8713 guardado con 10000 registros.
# 💾 Chunk 8714 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-West_Virginia/8.json (Estado: West_Virginia)
# 💾 Chunk 8715 guardado con 10000 registros.
# 💾 Chunk 8716 guardado con 10000 registros.
# 💾 Chunk 8717 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-South_Dakota/1.json (Estado: South_Dakota)
# 💾 Chunk 8718 guardado con 10000 registros.
# 💾 Chunk 8719 guardado con 10000 registros.
# 💾 Chunk 8720 guardado con 10000 registros.
# 💾 Chunk 8721 guardado con 10000 registros.
# 💾 Chunk 8722 guardado con 10000 registros.
# 💾 Chunk 8723 guardado con 10000 registros.
# 💾 Chunk 8724 guardado con 10000 registros.
# 💾 Chunk 8725 guardado con 10000 registros.
# 💾 Chunk 8726 guardado con 10000 registros.
# 💾 Chunk 8727 guardado con 10000 registros.
# 💾 Chunk 8728 guardado con 10000 registros.
# 💾 Chunk 8729 guardado con 10000 registros.
# 💾 Chunk 8730 guardado con 10000 registros.
# 💾 Chunk 8731 guardado con 10000 registros.
# 💾 Chunk 8732 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-South_Dakota/2.json (Estado: South_Dakota)
# 💾 Chunk 8733 guardado con 10000 registros.
# 💾 Chunk 8734 guardado con 10000 registros.
# 💾 Chunk 8735 guardado con 10000 registros.
# 💾 Chunk 8736 guardado con 10000 registros.
# 💾 Chunk 8737 guardado con 10000 registros.
# 💾 Chunk 8738 guardado con 10000 registros.
# 💾 Chunk 8739 guardado con 10000 registros.
# 💾 Chunk 8740 guardado con 10000 registros.
# 💾 Chunk 8741 guardado con 10000 registros.
# 💾 Chunk 8742 guardado con 10000 registros.
# 💾 Chunk 8743 guardado con 10000 registros.
# 💾 Chunk 8744 guardado con 10000 registros.
# 💾 Chunk 8745 guardado con 10000 registros.
# 💾 Chunk 8746 guardado con 10000 registros.
# 💾 Chunk 8747 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-South_Dakota/3.json (Estado: South_Dakota)
# 💾 Chunk 8748 guardado con 10000 registros.
# 💾 Chunk 8749 guardado con 10000 registros.
# 💾 Chunk 8750 guardado con 10000 registros.
# 💾 Chunk 8751 guardado con 10000 registros.
# 💾 Chunk 8752 guardado con 10000 registros.
# 💾 Chunk 8753 guardado con 10000 registros.
# 💾 Chunk 8754 guardado con 10000 registros.
# 💾 Chunk 8755 guardado con 10000 registros.
# 💾 Chunk 8756 guardado con 10000 registros.
# 💾 Chunk 8757 guardado con 10000 registros.
# 💾 Chunk 8758 guardado con 10000 registros.
# 💾 Chunk 8759 guardado con 10000 registros.
# 💾 Chunk 8760 guardado con 10000 registros.
# 💾 Chunk 8761 guardado con 10000 registros.
# 💾 Chunk 8762 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-South_Dakota/4.json (Estado: South_Dakota)
# 💾 Chunk 8763 guardado con 10000 registros.
# 💾 Chunk 8764 guardado con 10000 registros.
# 💾 Chunk 8765 guardado con 10000 registros.
# 💾 Chunk 8766 guardado con 10000 registros.
# 💾 Chunk 8767 guardado con 10000 registros.
# 💾 Chunk 8768 guardado con 10000 registros.
# 💾 Chunk 8769 guardado con 10000 registros.
# 💾 Chunk 8770 guardado con 10000 registros.
# 💾 Chunk 8771 guardado con 10000 registros.
# 💾 Chunk 8772 guardado con 10000 registros.
# 💾 Chunk 8773 guardado con 10000 registros.
# 💾 Chunk 8774 guardado con 10000 registros.
# 💾 Chunk 8775 guardado con 10000 registros.
# 💾 Chunk 8776 guardado con 10000 registros.
# 💾 Chunk 8777 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-South_Dakota/5.json (Estado: South_Dakota)
# 💾 Chunk 8778 guardado con 10000 registros.
# 💾 Chunk 8779 guardado con 10000 registros.
# 💾 Chunk 8780 guardado con 10000 registros.
# 💾 Chunk 8781 guardado con 10000 registros.
# 💾 Chunk 8782 guardado con 10000 registros.
# 💾 Chunk 8783 guardado con 10000 registros.
# 💾 Chunk 8784 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/1.json (Estado: Virginia)
# 💾 Chunk 8785 guardado con 10000 registros.
# 💾 Chunk 8786 guardado con 10000 registros.
# 💾 Chunk 8787 guardado con 10000 registros.
# 💾 Chunk 8788 guardado con 10000 registros.
# 💾 Chunk 8789 guardado con 10000 registros.
# 💾 Chunk 8790 guardado con 10000 registros.
# 💾 Chunk 8791 guardado con 10000 registros.
# 💾 Chunk 8792 guardado con 10000 registros.
# 💾 Chunk 8793 guardado con 10000 registros.
# 💾 Chunk 8794 guardado con 10000 registros.
# 💾 Chunk 8795 guardado con 10000 registros.
# 💾 Chunk 8796 guardado con 10000 registros.
# 💾 Chunk 8797 guardado con 10000 registros.
# 💾 Chunk 8798 guardado con 10000 registros.
# 💾 Chunk 8799 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/2.json (Estado: Virginia)
# 💾 Chunk 8800 guardado con 10000 registros.
# 💾 Chunk 8801 guardado con 10000 registros.
# 💾 Chunk 8802 guardado con 10000 registros.
# 💾 Chunk 8803 guardado con 10000 registros.
# 💾 Chunk 8804 guardado con 10000 registros.
# 💾 Chunk 8805 guardado con 10000 registros.
# 💾 Chunk 8806 guardado con 10000 registros.
# 💾 Chunk 8807 guardado con 10000 registros.
# 💾 Chunk 8808 guardado con 10000 registros.
# 💾 Chunk 8809 guardado con 10000 registros.
# 💾 Chunk 8810 guardado con 10000 registros.
# 💾 Chunk 8811 guardado con 10000 registros.
# 💾 Chunk 8812 guardado con 10000 registros.
# 💾 Chunk 8813 guardado con 10000 registros.
# 💾 Chunk 8814 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/3.json (Estado: Virginia)
# 💾 Chunk 8815 guardado con 10000 registros.
# 💾 Chunk 8816 guardado con 10000 registros.
# 💾 Chunk 8817 guardado con 10000 registros.
# 💾 Chunk 8818 guardado con 10000 registros.
# 💾 Chunk 8819 guardado con 10000 registros.
# 💾 Chunk 8820 guardado con 10000 registros.
# 💾 Chunk 8821 guardado con 10000 registros.
# 💾 Chunk 8822 guardado con 10000 registros.
# 💾 Chunk 8823 guardado con 10000 registros.
# 💾 Chunk 8824 guardado con 10000 registros.
# 💾 Chunk 8825 guardado con 10000 registros.
# 💾 Chunk 8826 guardado con 10000 registros.
# 💾 Chunk 8827 guardado con 10000 registros.
# 💾 Chunk 8828 guardado con 10000 registros.
# 💾 Chunk 8829 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/4.json (Estado: Virginia)
# 💾 Chunk 8830 guardado con 10000 registros.
# 💾 Chunk 8831 guardado con 10000 registros.
# 💾 Chunk 8832 guardado con 10000 registros.
# 💾 Chunk 8833 guardado con 10000 registros.
# 💾 Chunk 8834 guardado con 10000 registros.
# 💾 Chunk 8835 guardado con 10000 registros.
# 💾 Chunk 8836 guardado con 10000 registros.
# 💾 Chunk 8837 guardado con 10000 registros.
# 💾 Chunk 8838 guardado con 10000 registros.
# 💾 Chunk 8839 guardado con 10000 registros.
# 💾 Chunk 8840 guardado con 10000 registros.
# 💾 Chunk 8841 guardado con 10000 registros.
# 💾 Chunk 8842 guardado con 10000 registros.
# 💾 Chunk 8843 guardado con 10000 registros.
# 💾 Chunk 8844 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/5.json (Estado: Virginia)
# 💾 Chunk 8845 guardado con 10000 registros.
# 💾 Chunk 8846 guardado con 10000 registros.
# 💾 Chunk 8847 guardado con 10000 registros.
# 💾 Chunk 8848 guardado con 10000 registros.
# 💾 Chunk 8849 guardado con 10000 registros.
# 💾 Chunk 8850 guardado con 10000 registros.
# 💾 Chunk 8851 guardado con 10000 registros.
# 💾 Chunk 8852 guardado con 10000 registros.
# 💾 Chunk 8853 guardado con 10000 registros.
# 💾 Chunk 8854 guardado con 10000 registros.
# 💾 Chunk 8855 guardado con 10000 registros.
# 💾 Chunk 8856 guardado con 10000 registros.
# 💾 Chunk 8857 guardado con 10000 registros.
# 💾 Chunk 8858 guardado con 10000 registros.
# 💾 Chunk 8859 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/6.json (Estado: Virginia)
# 💾 Chunk 8860 guardado con 10000 registros.
# 💾 Chunk 8861 guardado con 10000 registros.
# 💾 Chunk 8862 guardado con 10000 registros.
# 💾 Chunk 8863 guardado con 10000 registros.
# 💾 Chunk 8864 guardado con 10000 registros.
# 💾 Chunk 8865 guardado con 10000 registros.
# 💾 Chunk 8866 guardado con 10000 registros.
# 💾 Chunk 8867 guardado con 10000 registros.
# 💾 Chunk 8868 guardado con 10000 registros.
# 💾 Chunk 8869 guardado con 10000 registros.
# 💾 Chunk 8870 guardado con 10000 registros.
# 💾 Chunk 8871 guardado con 10000 registros.
# 💾 Chunk 8872 guardado con 10000 registros.
# 💾 Chunk 8873 guardado con 10000 registros.
# 💾 Chunk 8874 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/7.json (Estado: Virginia)
# 💾 Chunk 8875 guardado con 10000 registros.
# 💾 Chunk 8876 guardado con 10000 registros.
# 💾 Chunk 8877 guardado con 10000 registros.
# 💾 Chunk 8878 guardado con 10000 registros.
# 💾 Chunk 8879 guardado con 10000 registros.
# 💾 Chunk 8880 guardado con 10000 registros.
# 💾 Chunk 8881 guardado con 10000 registros.
# 💾 Chunk 8882 guardado con 10000 registros.
# 💾 Chunk 8883 guardado con 10000 registros.
# 💾 Chunk 8884 guardado con 10000 registros.
# 💾 Chunk 8885 guardado con 10000 registros.
# 💾 Chunk 8886 guardado con 10000 registros.
# 💾 Chunk 8887 guardado con 10000 registros.
# 💾 Chunk 8888 guardado con 10000 registros.
# 💾 Chunk 8889 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/8.json (Estado: Virginia)
# 💾 Chunk 8890 guardado con 10000 registros.
# 💾 Chunk 8891 guardado con 10000 registros.
# 💾 Chunk 8892 guardado con 10000 registros.
# 💾 Chunk 8893 guardado con 10000 registros.
# 💾 Chunk 8894 guardado con 10000 registros.
# 💾 Chunk 8895 guardado con 10000 registros.
# 💾 Chunk 8896 guardado con 10000 registros.
# 💾 Chunk 8897 guardado con 10000 registros.
# 💾 Chunk 8898 guardado con 10000 registros.
# 💾 Chunk 8899 guardado con 10000 registros.
# 💾 Chunk 8900 guardado con 10000 registros.
# 💾 Chunk 8901 guardado con 10000 registros.
# 💾 Chunk 8902 guardado con 10000 registros.
# 💾 Chunk 8903 guardado con 10000 registros.
# 💾 Chunk 8904 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/9.json (Estado: Virginia)
# 💾 Chunk 8905 guardado con 10000 registros.
# 💾 Chunk 8906 guardado con 10000 registros.
# 💾 Chunk 8907 guardado con 10000 registros.
# 💾 Chunk 8908 guardado con 10000 registros.
# 💾 Chunk 8909 guardado con 10000 registros.
# 💾 Chunk 8910 guardado con 10000 registros.
# 💾 Chunk 8911 guardado con 10000 registros.
# 💾 Chunk 8912 guardado con 10000 registros.
# 💾 Chunk 8913 guardado con 10000 registros.
# 💾 Chunk 8914 guardado con 10000 registros.
# 💾 Chunk 8915 guardado con 10000 registros.
# 💾 Chunk 8916 guardado con 10000 registros.
# 💾 Chunk 8917 guardado con 10000 registros.
# 💾 Chunk 8918 guardado con 10000 registros.
# 💾 Chunk 8919 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/10.json (Estado: Virginia)
# 💾 Chunk 8920 guardado con 10000 registros.
# 💾 Chunk 8921 guardado con 10000 registros.
# 💾 Chunk 8922 guardado con 10000 registros.
# 💾 Chunk 8923 guardado con 10000 registros.
# 💾 Chunk 8924 guardado con 10000 registros.
# 💾 Chunk 8925 guardado con 10000 registros.
# 💾 Chunk 8926 guardado con 10000 registros.
# 💾 Chunk 8927 guardado con 10000 registros.
# 💾 Chunk 8928 guardado con 10000 registros.
# 💾 Chunk 8929 guardado con 10000 registros.
# 💾 Chunk 8930 guardado con 10000 registros.
# 💾 Chunk 8931 guardado con 10000 registros.
# 💾 Chunk 8932 guardado con 10000 registros.
# 💾 Chunk 8933 guardado con 10000 registros.
# 💾 Chunk 8934 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/11.json (Estado: Virginia)
# 💾 Chunk 8935 guardado con 10000 registros.
# 💾 Chunk 8936 guardado con 10000 registros.
# 💾 Chunk 8937 guardado con 10000 registros.
# 💾 Chunk 8938 guardado con 10000 registros.
# 💾 Chunk 8939 guardado con 10000 registros.
# 💾 Chunk 8940 guardado con 10000 registros.
# 💾 Chunk 8941 guardado con 10000 registros.
# 💾 Chunk 8942 guardado con 10000 registros.
# 💾 Chunk 8943 guardado con 10000 registros.
# 💾 Chunk 8944 guardado con 10000 registros.
# 💾 Chunk 8945 guardado con 10000 registros.
# 💾 Chunk 8946 guardado con 10000 registros.
# 💾 Chunk 8947 guardado con 10000 registros.
# 💾 Chunk 8948 guardado con 10000 registros.
# 💾 Chunk 8949 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Virginia/12.json (Estado: Virginia)
# 💾 Chunk 8950 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Wyoming/1.json (Estado: Wyoming)
# 💾 Chunk 8951 guardado con 10000 registros.
# 💾 Chunk 8952 guardado con 10000 registros.
# 💾 Chunk 8953 guardado con 10000 registros.
# 💾 Chunk 8954 guardado con 10000 registros.
# 💾 Chunk 8955 guardado con 10000 registros.
# 💾 Chunk 8956 guardado con 10000 registros.
# 💾 Chunk 8957 guardado con 10000 registros.
# 💾 Chunk 8958 guardado con 10000 registros.
# 💾 Chunk 8959 guardado con 10000 registros.
# 💾 Chunk 8960 guardado con 10000 registros.
# 💾 Chunk 8961 guardado con 10000 registros.
# 💾 Chunk 8962 guardado con 10000 registros.
# 💾 Chunk 8963 guardado con 10000 registros.
# 💾 Chunk 8964 guardado con 10000 registros.
# 💾 Chunk 8965 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Wyoming/2.json (Estado: Wyoming)
# 💾 Chunk 8966 guardado con 10000 registros.
# 💾 Chunk 8967 guardado con 10000 registros.
# 💾 Chunk 8968 guardado con 10000 registros.
# 💾 Chunk 8969 guardado con 10000 registros.
# 💾 Chunk 8970 guardado con 10000 registros.
# 💾 Chunk 8971 guardado con 10000 registros.
# 💾 Chunk 8972 guardado con 10000 registros.
# 💾 Chunk 8973 guardado con 10000 registros.
# 💾 Chunk 8974 guardado con 10000 registros.
# 💾 Chunk 8975 guardado con 10000 registros.
# 💾 Chunk 8976 guardado con 10000 registros.
# 💾 Chunk 8977 guardado con 10000 registros.
# 💾 Chunk 8978 guardado con 10000 registros.
# 💾 Chunk 8979 guardado con 10000 registros.
# 💾 Chunk 8980 guardado con 10000 registros.
# 📄 Procesando archivo: /content/drive/MyDrive/Google Maps/reviews-estados/review-Wyoming/3.json (Estado: Wyoming)
# 💾 Chunk 8981 guardado con 10000 registros.
# 💾 Chunk 8982 guardado con 10000 registros.
# 💾 Chunk 8983 guardado con 10000 registros.
# 💾 Chunk 8984 guardado con 10000 registros.
# 💾 Chunk 8985 guardado con 10000 registros.
# 💾 Chunk 8986 guardado con 10000 registros.
# 💾 Chunk 8987 guardado con 10000 registros.
# 💾 Chunk 8988 guardado con 10000 registros.
# 💾 Chunk 8989 guardado con 10000 registros.
# 💾 Chunk 8990 guardado con 10000 registros.
# 💾 Chunk 8991 guardado con 10000 registros.
# 💾 Chunk 8992 guardado con 10000 registros.
# 💾 Chunk 8993 guardado con 10000 registros.
# 💾 Último chunk 8994 guardado con 6359 registros.

# %%
import os
import glob
import pyarrow.parquet as pq
import pyarrow as pa
import pandas as pd

parquet_files = glob.glob(os.path.join(salida_dir, 'chunk_*.parquet'))

# Leer el primer archivo y obtener las columnas base
df_base = pd.read_parquet(parquet_files[0])
columnas_base = df_base.columns
schema = pa.Table.from_pandas(df_base).schema

output_path = os.path.join(salida_dir, 'aa_unificado.parquet')

with pq.ParquetWriter(output_path, schema) as writer:
    for pq_file in parquet_files:
        df = pd.read_parquet(pq_file)
        # Reindex para que todas tengan las mismas columnas, rellenando con NaN si falta alguna
        df = df.reindex(columns=columnas_base)
        table = pa.Table.from_pandas(df, schema=schema)
        writer.write_table(table)
        print(f"✅ Escrito {pq_file}")

print("✅ Archivo final unido guardado.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-862c8a7b4223> in <cell line: 0>()
#       5 import pandas as pd
#       6
# ----> 7 parquet_files = glob.glob(os.path.join(salida_dir, 'chunk_*.parquet'))
#       8
#       9 # Leer el primer archivo y obtener las columnas base
#
# NameError: name 'salida_dir' is not defined

# %%
import dask.dataframe as dd

# Carga sin meterlo todo en RAM
ddf = dd.read_parquet('/content/drive/MyDrive/Descargados de Colab/parquets_chunks_reviews/aa_unificado.parquet')

# Solo las primeras filas
df_sample = ddf.head(1000)  # Esto sí lo carga a pandas, pero solo esas filas

# Verifica
print(df_sample.shape)
print(df_sample.head())
# Out:
# (1000, 42)
#                  user_id                     name           time  rating  \
# 0  113766065560016413369           TheDiamondDave  1617676778946       5
# 1  116151043210713142064           Kathy Marshall  1612038163606       5
# 2  116088685202086458845          Teresa Ferguson  1602962017110       5
# 3  103082764991629671969  Country Strong Outdoors  1612852861583       4
# 4  106923743092573625151            Sierra Curtis  1610936215696       5
#
#                                                 text  pics  resp  \
# 0  Good supply of products friendly staff ! Close...   NaN   NaN
# 1      Awesome store so very helpful. Thanks so much   NaN   NaN
# 2  Opening weekend for the new location! I am so ...   NaN   NaN
# 3  Love Tractor supply but not crazy about the wa...   NaN   NaN
# 4  We go here every two weeks to pick up supplies...   NaN   NaN
#
#                                 gmap_id          estado pics_0_url_0  ...  \
# 0  0x88584f6e2704ff77:0x5ed0a4b5967575a  South_Carolina         <NA>  ...
# 1  0x88584f6e2704ff77:0x5ed0a4b5967575a  South_Carolina         <NA>  ...
# 2  0x88584f6e2704ff77:0x5ed0a4b5967575a  South_Carolina         <NA>  ...
# 3  0x88584f6e2704ff77:0x5ed0a4b5967575a  South_Carolina         <NA>  ...
# 4  0x88584f6e2704ff77:0x5ed0a4b5967575a  South_Carolina         <NA>  ...
#
#    pics_21_url_0 pics_22_url_0 pics_23_url_0 pics_24_url_0 pics_25_url_0  \
# 0           <NA>          <NA>          <NA>          <NA>          <NA>
# 1           <NA>          <NA>          <NA>          <NA>          <NA>
# 2           <NA>          <NA>          <NA>          <NA>          <NA>
# 3           <NA>          <NA>          <NA>          <NA>          <NA>
# 4           <NA>          <NA>          <NA>          <NA>          <NA>
#
#   pics_26_url_0 pics_27_url_0 pics_28_url_0 pics_29_url_0 pics_30_url_0
# 0          <NA>          <NA>          <NA>          <NA>          <NA>
# 1          <NA>          <NA>          <NA>          <NA>          <NA>
# 2          <NA>          <NA>          <NA>          <NA>          <NA>
# 3          <NA>          <NA>          <NA>          <NA>          <NA>
# 4          <NA>          <NA>          <NA>          <NA>          <NA>
#
# [5 rows x 42 columns]
